# %%
import pandas as pd
import numpy as np
df = pd.read_csv('orders/orders.csv')

# %%
product=pd.read_csv('products/products.csv')
product=product.head(n=49688//4)

# %%
final= pd.merge(df, product, on="product_id")
final
# Out:
#         order_id  product_id  add_to_cart_order  reordered  \
# 0              1       11109                  2          1
# 1          68474       11109                  8          1
# 2          78197       11109                  3          1
# 3         120619       11109                  1          0
# 4         128666       11109                 12          1
# ...          ...         ...                ...        ...
# 309672   3417904        6791                 13          0
# 309673   3418564        9073                 29          0
# 309674   3419375        8360                 12          0
# 309675   3420011        1528                 12          0
# 309676   3420084        9491                 21          0
#
#                                          product_name  aisle_id  department_id
# 0       Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 1       Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 2       Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 3       Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 4       Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# ...                                               ...       ...            ...
# 309672             Low Fat Blueberry Goat Milk Yogurt       120             16
# 309673                 Fire Roasted Whole Red Peppers        81             15
# 309674            Traditional Unseasoned Bread Crumbs         5             13
# 309675                               Sprinkles Decors        97             13
# 309676                         Goats Milk & Chai Soap        25             11
#
# [309677 rows x 7 columns]

# %%
orders=final.values.tolist()
orders
# Out:
# [[1, 11109, 2, 1, 'Organic 4% Milk Fat Whole Milk Cottage Cheese', 108, 16],
#  [68474,
#   11109,
#   8,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [78197,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [120619,
#   11109,
#   1,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [128666,
#   11109,
#   12,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [153973,
#   11109,
#   10,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [193761,
#   11109,
#   2,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [213799,
#   11109,
#   6,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [214201,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [228214,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [245323,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [253424,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [309008,
#   11109,
#   5,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [332153,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [333127,
#   11109,
#   6,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [338460,
#   11109,
#   6,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [347470,
#   11109,
#   5,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [399998,
#   11109,
#   6,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [404233,
#   11109,
#   7,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [449658,
#   11109,
#   9,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [462593,
#   11109,
#   11,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [485991,
#   11109,
#   16,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [513953,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [543333,
#   11109,
#   12,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [547424,
#   11109,
#   2,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [552425,
#   11109,
#   6,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [567963,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [583113,
#   11109,
#   8,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [598693,
#   11109,
#   11,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [684993,
#   11109,
#   1,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [687429,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [688331,
#   11109,
#   14,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [712453,
#   11109,
#   10,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [739022,
#   11109,
#   26,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [747775,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [763067,
#   11109,
#   8,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [787916,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [809611,
#   11109,
#   13,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [812827,
#   11109,
#   12,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [850681,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [883854,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [912431,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [945580,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [958982,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [984899,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [995322,
#   11109,
#   11,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [995649,
#   11109,
#   10,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [999068,
#   11109,
#   1,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [999426,
#   11109,
#   7,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1033471,
#   11109,
#   20,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1048369,
#   11109,
#   12,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1073470,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1080121,
#   11109,
#   15,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1083650,
#   11109,
#   5,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1086806,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1092658,
#   11109,
#   8,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1096015,
#   11109,
#   22,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1104263,
#   11109,
#   13,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1160601,
#   11109,
#   6,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1161224,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1164874,
#   11109,
#   6,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1197502,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1204677,
#   11109,
#   4,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1207554,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1311414,
#   11109,
#   4,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1328592,
#   11109,
#   5,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1362813,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1408967,
#   11109,
#   3,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1416953,
#   11109,
#   5,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1425911,
#   11109,
#   7,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1426828,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1451098,
#   11109,
#   5,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1465854,
#   11109,
#   5,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1466561,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1467709,
#   11109,
#   8,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1471547,
#   11109,
#   14,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1496326,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1535966,
#   11109,
#   17,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1536640,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1672368,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1685847,
#   11109,
#   33,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1693423,
#   11109,
#   10,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1700328,
#   11109,
#   26,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1784784,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1818112,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1838673,
#   11109,
#   8,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1844609,
#   11109,
#   10,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1864299,
#   11109,
#   16,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1874211,
#   11109,
#   6,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1904854,
#   11109,
#   11,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1984634,
#   11109,
#   11,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2035104,
#   11109,
#   12,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2051573,
#   11109,
#   1,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2093311,
#   11109,
#   8,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2122538,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2134172,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2135811,
#   11109,
#   24,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2141488,
#   11109,
#   16,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2176024,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2215509,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2264496,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2299865,
#   11109,
#   8,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2310164,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2335808,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2364762,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2455875,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2476187,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2484958,
#   11109,
#   13,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2506581,
#   11109,
#   27,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2540385,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2547158,
#   11109,
#   2,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2549790,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2554762,
#   11109,
#   7,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2566803,
#   11109,
#   5,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2591942,
#   11109,
#   14,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2633801,
#   11109,
#   7,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2640788,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2646613,
#   11109,
#   14,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2704966,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2711771,
#   11109,
#   20,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2763636,
#   11109,
#   17,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2770555,
#   11109,
#   19,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2788401,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2789939,
#   11109,
#   11,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2838740,
#   11109,
#   10,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2841082,
#   11109,
#   11,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2866129,
#   11109,
#   4,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2895978,
#   11109,
#   17,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2974142,
#   11109,
#   9,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [2997017,
#   11109,
#   6,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3069692,
#   11109,
#   8,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3069893,
#   11109,
#   5,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3078671,
#   11109,
#   18,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3087122,
#   11109,
#   6,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3192384,
#   11109,
#   3,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3245375,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3257274,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3267259,
#   11109,
#   6,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3271043,
#   11109,
#   5,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3292791,
#   11109,
#   20,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3350815,
#   11109,
#   12,
#   0,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3387069,
#   11109,
#   28,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3414087,
#   11109,
#   1,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [3418547,
#   11109,
#   4,
#   1,
#   'Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   108,
#   16],
#  [1, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [2869, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [3378, 10246, 19, 0, 'Organic Celery Hearts', 83, 4],
#  [14119, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [17152, 10246, 22, 1, 'Organic Celery Hearts', 83, 4],
#  [18271, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [19552, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [20632, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [22596, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [23669, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [28841, 10246, 20, 1, 'Organic Celery Hearts', 83, 4],
#  [30009, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [30069, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [32361, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [33622, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [35235, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [43194, 10246, 27, 0, 'Organic Celery Hearts', 83, 4],
#  [44972, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [53395, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [56661, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [57105, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [57650, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [57969, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [58309, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [58692, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [73280, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [74103, 10246, 17, 1, 'Organic Celery Hearts', 83, 4],
#  [75339, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [77034, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [80489, 10246, 25, 0, 'Organic Celery Hearts', 83, 4],
#  [82890, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [83612, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [83849, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [84509, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [84713, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [87289, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [92892, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [99690, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [108042, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [113486, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [122499, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [126300, 10246, 19, 1, 'Organic Celery Hearts', 83, 4],
#  [127343, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [127980, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [129002, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [129325, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [131931, 10246, 36, 0, 'Organic Celery Hearts', 83, 4],
#  [134443, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [138718, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [139859, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [141857, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [143716, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [148866, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [149851, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [153408, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [158134, 10246, 30, 0, 'Organic Celery Hearts', 83, 4],
#  [159070, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [161714, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [164723, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [178513, 10246, 39, 0, 'Organic Celery Hearts', 83, 4],
#  [181697, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [184838, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [186472, 10246, 20, 0, 'Organic Celery Hearts', 83, 4],
#  [196261, 10246, 20, 1, 'Organic Celery Hearts', 83, 4],
#  [197937, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [202566, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [203202, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [204051, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [204137, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [208777, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [214631, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [216322, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [218591, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [218991, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [225335, 10246, 29, 0, 'Organic Celery Hearts', 83, 4],
#  [225830, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [236867, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [241789, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [242990, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [245864, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [251773, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [253246, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [255087, 10246, 22, 0, 'Organic Celery Hearts', 83, 4],
#  [255114, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [256718, 10246, 31, 1, 'Organic Celery Hearts', 83, 4],
#  [259316, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [260832, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [262777, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [265454, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [267497, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [274329, 10246, 38, 1, 'Organic Celery Hearts', 83, 4],
#  [275022, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [280429, 10246, 25, 1, 'Organic Celery Hearts', 83, 4],
#  [282974, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [284437, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [286778, 10246, 21, 0, 'Organic Celery Hearts', 83, 4],
#  [296543, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [299877, 10246, 25, 0, 'Organic Celery Hearts', 83, 4],
#  [305163, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [309893, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [314104, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [314645, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [315537, 10246, 17, 1, 'Organic Celery Hearts', 83, 4],
#  [318102, 10246, 33, 0, 'Organic Celery Hearts', 83, 4],
#  [319059, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [323610, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [324130, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [328038, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [330702, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [332738, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [341729, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [344189, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [345095, 10246, 34, 0, 'Organic Celery Hearts', 83, 4],
#  [346585, 10246, 22, 1, 'Organic Celery Hearts', 83, 4],
#  [347106, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [347550, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [348799, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [349890, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [353530, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [355325, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [357137, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [358267, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [358979, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [363155, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [366976, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [367796, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [375735, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [376290, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [377805, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [379551, 10246, 23, 0, 'Organic Celery Hearts', 83, 4],
#  [384413, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [386932, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [389275, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [392233, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [396173, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [400091, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [401301, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [403721, 10246, 19, 0, 'Organic Celery Hearts', 83, 4],
#  [404170, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [411391, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [420820, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [432968, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [440925, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [443840, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [444377, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [448872, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [449658, 10246, 23, 1, 'Organic Celery Hearts', 83, 4],
#  [450379, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [453759, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [455476, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [456394, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [457738, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [459487, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [462865, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [463633, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [466831, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [469192, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [477144, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [478112, 10246, 17, 0, 'Organic Celery Hearts', 83, 4],
#  [478137, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [481137, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [485339, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [489374, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [498171, 10246, 20, 1, 'Organic Celery Hearts', 83, 4],
#  [502132, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [511521, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [512968, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [514343, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [516844, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [517871, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [520482, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [524617, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [525223, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [525937, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [530591, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [531272, 10246, 26, 1, 'Organic Celery Hearts', 83, 4],
#  [531299, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [533562, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [534263, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [535974, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [536530, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [537550, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [539401, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [545319, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [547318, 10246, 23, 0, 'Organic Celery Hearts', 83, 4],
#  [547558, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [550240, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [551813, 10246, 21, 0, 'Organic Celery Hearts', 83, 4],
#  [553754, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [554703, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [563878, 10246, 16, 0, 'Organic Celery Hearts', 83, 4],
#  [564576, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [566423, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [567673, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [569478, 10246, 17, 1, 'Organic Celery Hearts', 83, 4],
#  [571524, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [574845, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [588768, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [590948, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [591133, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [591165, 10246, 17, 0, 'Organic Celery Hearts', 83, 4],
#  [593194, 10246, 16, 0, 'Organic Celery Hearts', 83, 4],
#  [594619, 10246, 20, 1, 'Organic Celery Hearts', 83, 4],
#  [594759, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [596279, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [596600, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [601763, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [605135, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [608313, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [608474, 10246, 37, 1, 'Organic Celery Hearts', 83, 4],
#  [609243, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [612969, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [614290, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [615539, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [617389, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [617633, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [625600, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [629099, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [630523, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [630806, 10246, 25, 1, 'Organic Celery Hearts', 83, 4],
#  [634381, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [637553, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [641062, 10246, 23, 0, 'Organic Celery Hearts', 83, 4],
#  [646752, 10246, 22, 1, 'Organic Celery Hearts', 83, 4],
#  [651855, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [655265, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [656168, 10246, 16, 1, 'Organic Celery Hearts', 83, 4],
#  [662357, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [666964, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [669276, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [671703, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [672042, 10246, 25, 1, 'Organic Celery Hearts', 83, 4],
#  [673896, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [677842, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [680616, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [686547, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [696465, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [696736, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [697895, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [698448, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [705624, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [705870, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [708480, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [710233, 10246, 26, 0, 'Organic Celery Hearts', 83, 4],
#  [713633, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [719080, 10246, 16, 0, 'Organic Celery Hearts', 83, 4],
#  [719803, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [719848, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [729404, 10246, 20, 1, 'Organic Celery Hearts', 83, 4],
#  [735666, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [741554, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [744653, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [748715, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [751811, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [755195, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [755596, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [765284, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [768173, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [768558, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [769906, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [774356, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [791283, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [795157, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [806390, 10246, 23, 0, 'Organic Celery Hearts', 83, 4],
#  [809276, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [809290, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [812827, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [815402, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [818333, 10246, 23, 1, 'Organic Celery Hearts', 83, 4],
#  [819520, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [826933, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [829669, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [835864, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [851675, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [851779, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [851824, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [853993, 10246, 31, 0, 'Organic Celery Hearts', 83, 4],
#  [856974, 10246, 17, 1, 'Organic Celery Hearts', 83, 4],
#  [857861, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [858413, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [860048, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [863139, 10246, 26, 1, 'Organic Celery Hearts', 83, 4],
#  [864893, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [865719, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [871181, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [871284, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [875597, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [878368, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [887186, 10246, 17, 1, 'Organic Celery Hearts', 83, 4],
#  [905760, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [906589, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [907951, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [909489, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [921138, 10246, 26, 0, 'Organic Celery Hearts', 83, 4],
#  [922720, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [925379, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [926496, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [931183, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [935325, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [940288, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [940810, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [947646, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [948095, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [949365, 10246, 17, 1, 'Organic Celery Hearts', 83, 4],
#  [950516, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [953116, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [953497, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [954418, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [960675, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [962241, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [964245, 10246, 27, 1, 'Organic Celery Hearts', 83, 4],
#  [965515, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [966108, 10246, 26, 1, 'Organic Celery Hearts', 83, 4],
#  [970952, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [970974, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [978545, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [979384, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [981623, 10246, 19, 1, 'Organic Celery Hearts', 83, 4],
#  [985271, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [991287, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [992621, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [995722, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [996139, 10246, 34, 0, 'Organic Celery Hearts', 83, 4],
#  [1004492, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [1009641, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1010989, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1015219, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1016640, 10246, 20, 0, 'Organic Celery Hearts', 83, 4],
#  [1018425, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [1019719, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1021592, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1027853, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1033471, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1036766, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1038731, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1048675, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1049334, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1051870, 10246, 35, 1, 'Organic Celery Hearts', 83, 4],
#  [1052910, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1055000, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1064295, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1065078, 10246, 17, 0, 'Organic Celery Hearts', 83, 4],
#  [1067571, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [1073675, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1077077, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [1077506, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [1078074, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1079015, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1081770, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1087444, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1096121, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1096246, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1097326, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [1100266, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1100314, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1107560, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1117183, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [1118552, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1118691, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1119555, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [1120673, 10246, 24, 0, 'Organic Celery Hearts', 83, 4],
#  [1126262, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1127886, 10246, 16, 1, 'Organic Celery Hearts', 83, 4],
#  [1128834, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1131395, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [1133822, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1141873, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [1145186, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1152409, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [1155321, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [1160106, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1162375, 10246, 23, 0, 'Organic Celery Hearts', 83, 4],
#  [1162504, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [1164882, 10246, 20, 1, 'Organic Celery Hearts', 83, 4],
#  [1166491, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [1171204, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1171552, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1172576, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1172763, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [1180271, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1185569, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1187863, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [1197954, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1200992, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1202545, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1204868, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1209041, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [1210462, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1214423, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1216338, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [1218185, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1220993, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [1221460, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1221812, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1223899, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1225613, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1232685, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [1233616, 10246, 59, 0, 'Organic Celery Hearts', 83, 4],
#  [1233779, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1244073, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1254958, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1255164, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [1255784, 10246, 25, 1, 'Organic Celery Hearts', 83, 4],
#  [1260727, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [1266259, 10246, 27, 0, 'Organic Celery Hearts', 83, 4],
#  [1266753, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1268231, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1271264, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [1278097, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1280731, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [1281573, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [1282002, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1282203, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1283574, 10246, 20, 0, 'Organic Celery Hearts', 83, 4],
#  [1291088, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1291773, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1295985, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1304040, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [1308594, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [1312347, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1312635, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [1318662, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1321804, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1327498, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1329262, 10246, 19, 1, 'Organic Celery Hearts', 83, 4],
#  [1334191, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1338825, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [1346333, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [1354896, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1358062, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1358990, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [1360220, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1363365, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [1363964, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [1368339, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1370679, 10246, 19, 1, 'Organic Celery Hearts', 83, 4],
#  [1373323, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [1378011, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1379656, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1382773, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1390001, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1396003, 10246, 27, 1, 'Organic Celery Hearts', 83, 4],
#  [1396753, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [1396984, 10246, 19, 1, 'Organic Celery Hearts', 83, 4],
#  [1404328, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1410450, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1413909, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1418242, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1431732, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [1432206, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1438279, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1444505, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1445527, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [1447887, 10246, 31, 0, 'Organic Celery Hearts', 83, 4],
#  [1450064, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1451821, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1454237, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [1456391, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1463816, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1463997, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [1464759, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [1467258, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1470683, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [1480751, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [1485878, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1491728, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [1493086, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1496547, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1496836, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [1498827, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1499836, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [1504777, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1506598, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1508767, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [1510024, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [1511460, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1513334, 10246, 16, 1, 'Organic Celery Hearts', 83, 4],
#  [1522634, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1527190, 10246, 37, 0, 'Organic Celery Hearts', 83, 4],
#  [1537837, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1538719, 10246, 30, 0, 'Organic Celery Hearts', 83, 4],
#  [1539579, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1542096, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1543234, 10246, 20, 0, 'Organic Celery Hearts', 83, 4],
#  [1547218, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1548645, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [1559377, 10246, 16, 0, 'Organic Celery Hearts', 83, 4],
#  [1561855, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1569241, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1571962, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [1575746, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1576281, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [1586427, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [1588172, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1594464, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1598256, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [1601686, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1605016, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1608036, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1619828, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [1625630, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [1629596, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [1644965, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1656366, 10246, 16, 1, 'Organic Celery Hearts', 83, 4],
#  [1658723, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [1658861, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1664187, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1672292, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1675965, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1677690, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1678677, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1685768, 10246, 35, 1, 'Organic Celery Hearts', 83, 4],
#  [1685847, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [1688988, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [1689866, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1691414, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [1691706, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1691953, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [1698556, 10246, 21, 1, 'Organic Celery Hearts', 83, 4],
#  [1699674, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1700629, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1701505, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [1702271, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [1709608, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1711846, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1714856, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [1724050, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [1724239, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [1726565, 10246, 23, 0, 'Organic Celery Hearts', 83, 4],
#  [1732518, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [1737098, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1738513, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1739700, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [1742627, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1742986, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [1743965, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1745551, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [1756231, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1759680, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1760122, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1760682, 10246, 20, 1, 'Organic Celery Hearts', 83, 4],
#  [1761618, 10246, 17, 0, 'Organic Celery Hearts', 83, 4],
#  [1765172, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [1766346, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [1768032, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [1773131, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1778071, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1780084, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1781773, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1782253, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1796470, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [1800825, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [1809607, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [1813947, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [1816466, 10246, 21, 1, 'Organic Celery Hearts', 83, 4],
#  [1822721, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1823436, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1825446, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1826199, 10246, 20, 1, 'Organic Celery Hearts', 83, 4],
#  [1829859, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1834363, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1834623, 10246, 36, 1, 'Organic Celery Hearts', 83, 4],
#  [1840072, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1840891, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [1841607, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [1845035, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [1846927, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1848749, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [1853662, 10246, 22, 1, 'Organic Celery Hearts', 83, 4],
#  [1865220, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1870746, 10246, 16, 1, 'Organic Celery Hearts', 83, 4],
#  [1872474, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [1872929, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1872961, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [1874307, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1875986, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [1877898, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [1880431, 10246, 37, 0, 'Organic Celery Hearts', 83, 4],
#  [1884866, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [1887316, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [1893259, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [1901320, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1901957, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [1903046, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [1905411, 10246, 22, 0, 'Organic Celery Hearts', 83, 4],
#  [1914888, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1926252, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [1928283, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [1935911, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1936815, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [1949846, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [1951985, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [1971153, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [1980144, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [1984652, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [1985257, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [1986488, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [1993100, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [1996677, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2008775, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [2009673, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [2016954, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2023825, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [2027944, 10246, 24, 0, 'Organic Celery Hearts', 83, 4],
#  [2028060, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2028825, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [2028943, 10246, 32, 0, 'Organic Celery Hearts', 83, 4],
#  [2029736, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [2041220, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [2041815, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [2046670, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2050298, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [2051163, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2052081, 10246, 19, 0, 'Organic Celery Hearts', 83, 4],
#  [2053602, 10246, 22, 0, 'Organic Celery Hearts', 83, 4],
#  [2055343, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [2056988, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [2059324, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2064754, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [2065119, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [2066279, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [2068993, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [2071456, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2072648, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [2078734, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [2082942, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2083108, 10246, 16, 0, 'Organic Celery Hearts', 83, 4],
#  [2086823, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [2088197, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [2088323, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [2104764, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [2108483, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [2108642, 10246, 24, 1, 'Organic Celery Hearts', 83, 4],
#  [2113817, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2116012, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [2116139, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2119812, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2120086, 10246, 22, 1, 'Organic Celery Hearts', 83, 4],
#  [2120362, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [2123344, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [2124041, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2125659, 10246, 39, 0, 'Organic Celery Hearts', 83, 4],
#  [2129128, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [2131618, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [2136021, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2139845, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2148054, 10246, 26, 1, 'Organic Celery Hearts', 83, 4],
#  [2148873, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [2152745, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [2154131, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2163629, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [2165705, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [2169001, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [2169488, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2170169, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [2171084, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [2172242, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [2175237, 10246, 17, 0, 'Organic Celery Hearts', 83, 4],
#  [2178689, 10246, 23, 1, 'Organic Celery Hearts', 83, 4],
#  [2185528, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [2197222, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [2204297, 10246, 27, 0, 'Organic Celery Hearts', 83, 4],
#  [2206976, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2208652, 10246, 22, 0, 'Organic Celery Hearts', 83, 4],
#  [2210334, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [2212948, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [2214798, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [2218116, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [2222718, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [2229785, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [2232767, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [2238400, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [2244363, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2247909, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2254238, 10246, 12, 1, 'Organic Celery Hearts', 83, 4],
#  [2263911, 10246, 20, 0, 'Organic Celery Hearts', 83, 4],
#  [2276536, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [2278220, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2278434, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [2279256, 10246, 34, 0, 'Organic Celery Hearts', 83, 4],
#  [2292317, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [2301215, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [2303479, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2312684, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2313977, 10246, 16, 0, 'Organic Celery Hearts', 83, 4],
#  [2315444, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [2316142, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [2317982, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2322878, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [2326863, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2340860, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2347194, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [2349884, 10246, 19, 0, 'Organic Celery Hearts', 83, 4],
#  [2361611, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [2367360, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [2370214, 10246, 21, 0, 'Organic Celery Hearts', 83, 4],
#  [2376364, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2376859, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2376870, 10246, 26, 0, 'Organic Celery Hearts', 83, 4],
#  [2383273, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [2384460, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2395035, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2397711, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [2405428, 10246, 34, 1, 'Organic Celery Hearts', 83, 4],
#  [2408215, 10246, 17, 0, 'Organic Celery Hearts', 83, 4],
#  [2408931, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [2409283, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [2411855, 10246, 26, 0, 'Organic Celery Hearts', 83, 4],
#  [2418527, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2418673, 10246, 19, 1, 'Organic Celery Hearts', 83, 4],
#  [2424590, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [2425121, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [2425244, 10246, 16, 1, 'Organic Celery Hearts', 83, 4],
#  [2428914, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [2431518, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2433938, 10246, 16, 0, 'Organic Celery Hearts', 83, 4],
#  [2449436, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2449746, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [2450878, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [2452843, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2456312, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [2457362, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [2464699, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2477515, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [2481013, 10246, 17, 0, 'Organic Celery Hearts', 83, 4],
#  [2482038, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [2483332, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [2485096, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [2486060, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [2491354, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2492627, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2495722, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [2495788, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [2499519, 10246, 10, 0, 'Organic Celery Hearts', 83, 4],
#  [2499709, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2504312, 10246, 18, 1, 'Organic Celery Hearts', 83, 4],
#  [2507235, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [2514417, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2516265, 10246, 22, 1, 'Organic Celery Hearts', 83, 4],
#  [2516470, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2517381, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [2523744, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2524180, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2531422, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [2532022, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2533447, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2534136, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [2534608, 10246, 18, 0, 'Organic Celery Hearts', 83, 4],
#  [2537638, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [2540167, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2543751, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [2545323, 10246, 7, 1, 'Organic Celery Hearts', 83, 4],
#  [2545551, 10246, 17, 1, 'Organic Celery Hearts', 83, 4],
#  [2546332, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2549679, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2556921, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [2556940, 10246, 31, 0, 'Organic Celery Hearts', 83, 4],
#  [2557433, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [2562200, 10246, 15, 1, 'Organic Celery Hearts', 83, 4],
#  [2562925, 10246, 24, 1, 'Organic Celery Hearts', 83, 4],
#  [2566803, 10246, 11, 1, 'Organic Celery Hearts', 83, 4],
#  [2571006, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2574447, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2575586, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2577312, 10246, 7, 0, 'Organic Celery Hearts', 83, 4],
#  [2583012, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [2589672, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [2590741, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [2591821, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2594485, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2598678, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2599750, 10246, 16, 0, 'Organic Celery Hearts', 83, 4],
#  [2600805, 10246, 1, 0, 'Organic Celery Hearts', 83, 4],
#  [2601468, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2610040, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2610387, 10246, 17, 0, 'Organic Celery Hearts', 83, 4],
#  [2614217, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [2614366, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [2617265, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2617766, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2619638, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [2629165, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2629779, 10246, 29, 1, 'Organic Celery Hearts', 83, 4],
#  [2630780, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [2632390, 10246, 32, 1, 'Organic Celery Hearts', 83, 4],
#  [2636185, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [2636459, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [2643097, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [2644254, 10246, 22, 0, 'Organic Celery Hearts', 83, 4],
#  [2650993, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2652584, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [2656855, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2666153, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [2666849, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2667193, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2667493, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [2677668, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [2683177, 10246, 8, 0, 'Organic Celery Hearts', 83, 4],
#  [2687260, 10246, 5, 0, 'Organic Celery Hearts', 83, 4],
#  [2690463, 10246, 11, 0, 'Organic Celery Hearts', 83, 4],
#  [2690560, 10246, 22, 0, 'Organic Celery Hearts', 83, 4],
#  [2690791, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2691084, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2695061, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2696643, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2703181, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [2705139, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [2706556, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2709723, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2713402, 10246, 12, 0, 'Organic Celery Hearts', 83, 4],
#  [2717506, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [2722107, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2725651, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2727510, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [2728698, 10246, 22, 1, 'Organic Celery Hearts', 83, 4],
#  [2731305, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [2733086, 10246, 3, 0, 'Organic Celery Hearts', 83, 4],
#  [2733264, 10246, 19, 1, 'Organic Celery Hearts', 83, 4],
#  [2737435, 10246, 42, 1, 'Organic Celery Hearts', 83, 4],
#  [2737490, 10246, 6, 0, 'Organic Celery Hearts', 83, 4],
#  [2739002, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2739151, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [2749097, 10246, 36, 1, 'Organic Celery Hearts', 83, 4],
#  [2754305, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [2756473, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [2756772, 10246, 9, 0, 'Organic Celery Hearts', 83, 4],
#  [2758538, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2761373, 10246, 10, 1, 'Organic Celery Hearts', 83, 4],
#  [2763283, 10246, 28, 1, 'Organic Celery Hearts', 83, 4],
#  [2766170, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  [2767214, 10246, 14, 0, 'Organic Celery Hearts', 83, 4],
#  [2774370, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [2775649, 10246, 8, 1, 'Organic Celery Hearts', 83, 4],
#  [2776395, 10246, 29, 0, 'Organic Celery Hearts', 83, 4],
#  [2783312, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2788078, 10246, 24, 1, 'Organic Celery Hearts', 83, 4],
#  [2792510, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2792816, 10246, 16, 1, 'Organic Celery Hearts', 83, 4],
#  [2793593, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2795721, 10246, 3, 1, 'Organic Celery Hearts', 83, 4],
#  [2798992, 10246, 14, 1, 'Organic Celery Hearts', 83, 4],
#  [2799139, 10246, 5, 1, 'Organic Celery Hearts', 83, 4],
#  [2799709, 10246, 13, 0, 'Organic Celery Hearts', 83, 4],
#  [2801375, 10246, 1, 1, 'Organic Celery Hearts', 83, 4],
#  [2803301, 10246, 4, 1, 'Organic Celery Hearts', 83, 4],
#  [2805183, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [2806282, 10246, 38, 0, 'Organic Celery Hearts', 83, 4],
#  [2807049, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2807967, 10246, 6, 1, 'Organic Celery Hearts', 83, 4],
#  [2808627, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [2810520, 10246, 2, 0, 'Organic Celery Hearts', 83, 4],
#  [2812469, 10246, 4, 0, 'Organic Celery Hearts', 83, 4],
#  [2812721, 10246, 2, 1, 'Organic Celery Hearts', 83, 4],
#  [2813769, 10246, 13, 1, 'Organic Celery Hearts', 83, 4],
#  [2816103, 10246, 15, 0, 'Organic Celery Hearts', 83, 4],
#  [2827178, 10246, 9, 1, 'Organic Celery Hearts', 83, 4],
#  ...]

# %%
transactions={}
for i in range(len(orders)):
    x=orders[i][0]
    if x in transactions:
        transactions[x].append(orders[i][4])
    else:
        transactions[x]=[orders[i][4]]
transactions
# Out:
# {1: ['Organic 4% Milk Fat Whole Milk Cottage Cheese', 'Organic Celery Hearts'],
#  68474: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Whole Milk Plain Yogurt',
#   'Organic Chicken & Apple Sausage',
#   'Organic Cream Cheese Bar',
#   'Yellow Onions',
#   'Organic Chicken Broth',
#   'Boneless Skinless Chicken Thighs'],
#  78197: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Spinach Pizza',
#   'Pizza 4 Cheese',
#   '100% Recycled Paper Towels',
#   'Vegetable Pot Pie'],
#  120619: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs'],
#  128666: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Breakfast Scramble Wrap'],
#  153973: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  193761: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs'],
#  213799: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'English Seedless Cucumber',
#   'White Onion',
#   'Organic Chicken Stock'],
#  214201: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Gluten Free Big Pretzels',
#   'Organic Uncured Beef Hot Dog',
#   'Organic Kale Pesto Hummus'],
#  228214: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Boneless Skinless Chicken Breast',
#   'Organic Whole Milk Plain Kefir',
#   'Organic Purple Kale',
#   'Organic All Day Fresh Deodorant Lavender'],
#  245323: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Unsalted Pure Irish Butter',
#   'Roasted Mushroom Pizza',
#   'Plain Soymilk Creamer'],
#  253424: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Hot Salsa',
#   'Organic Reduced Fat 2% Milk',
#   'Shredded Parmesan',
#   'Cheerios Cereal',
#   'Crunchy Peanut Butter',
#   'New Orleans Iced Coffee',
#   'Spicy Hummus',
#   'Olive & Avocado Hair Masque'],
#  309008: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Broccoli Crown',
#   'Small Hass Avocado',
#   'House Blend Deep Roast Ground Coffee',
#   'Organic Peeled & Cooked Beets',
#   'Organic Bagged Kale Salad Mix'],
#  332153: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Purity Farms Ghee Clarified Butter',
#   'Naturals Chicken Nuggets'],
#  333127: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  338460: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic 2% Reduced Fat Milk',
#   'Premium Original Saltine Crackers',
#   'Organic Salted Butter',
#   'Organic Cottage Cheese Classic',
#   'Organic Turkey Bone Broth',
#   'Hibiscus Mint Frozen Pops',
#   '8 Hot Dog Buns',
#   'Lemon Verbena Toilet Bowl Cleaner',
#   'Organic Vitality Snack Green Magic Chia'],
#  347470: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Taco Seasoning',
#   'Nonfat Icelandic Style Strawberry Yogurt'],
#  399998: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Chicken & Apple Sausage'],
#  404233: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese'],
#  449658: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Celery Hearts',
#   '100% Whole Wheat Bread',
#   'Broccoli Crown',
#   'Apple Honeycrisp Organic',
#   'Organic American Cheese Singles',
#   'Shredded Parmesan',
#   'Honey Yoghurt',
#   'Boneless Skinless Chicken Thighs',
#   'Organic Red Cherry Tomato',
#   'Original Bobos Bites',
#   'Black Forest Berry Caffeine-Free Tea'],
#  462593: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Apple Honeycrisp Organic',
#   'Yellow Onions',
#   'Naturals Chicken Nuggets',
#   'Organic Chicken Broth',
#   'Organic Carrots',
#   'Organic Shiitake Sesame Dressing',
#   'Organic Greek Blueberry Whole Milk'],
#  485991: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Organic Unsalted Butter',
#   'Instant Coffee',
#   'Country Morning White Bread',
#   'Organic Acai Berry Smoothie Packs',
#   'All Natural Sea Fresh Antiplaque & Strengthening Toothpaste Deep Sea Spearmint',
#   'Organic White Mushrooms',
#   'Camilia, Single Liquid Doses'],
#  513953: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Broccoli Crown',
#   'Apple Honeycrisp Organic',
#   'Organic Red Onion',
#   'Organic Cream Cheese Bar',
#   'Tater Puffs',
#   'Organic Purple Kale',
#   'Peppered Turkey Breast',
#   'Organic Homogenized Whole Milk',
#   'Tostones Plantain Patties'],
#  543333: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Broccoli',
#   'YoBaby Peach Pear Yogurt',
#   'Coconut Milk',
#   'Original Coconut Milk Creamer',
#   'Feta Cheese',
#   'Unsweetened Organic Coconut Milk',
#   'Organic Tomato Bisque'],
#  547424: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  552425: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Parsley, Italian (Flat), New England Grown',
#   'Organic Iceberg Lettuce',
#   'Pastured Eggs',
#   'Organic Alfalfa Sprouts',
#   'Laundry Detergent Free & Clear',
#   '100 % Recycled Paper Towels'],
#  567963: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Bunny Fruit Snacks Berry Patch',
#   'Organic Cheddar Bunnies',
#   'Roasted Sesame Seaweed Snacks',
#   'Dairy Free Gluten Free Mushroom & Roasted Garlic Pizza'],
#  583113: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Apple Honeycrisp Organic',
#   'Seedless Red Grapes',
#   'Organic Shredded Mild Cheddar',
#   'Roasted Red Pepper Hommus',
#   'Organic Lowfat Plain Yogurt'],
#  598693: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Broccoli Crown',
#   'Medium Cheddar Cheese Block'],
#  684993: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  687429: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Organic Broccoli'],
#  688331: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Mocha Almond Fudge Minis Almond Milk Frozen Dessert',
#   'Organic Chicken Broth',
#   'Honey Yoghurt',
#   'Ezekiel 4:9 Golden Flax Sprouted Grain Crunchy Cereal',
#   'Culinary Coconut Milk'],
#  712453: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Organic Red Bell Pepper',
#   'Whole Milk Plain Yogurt',
#   'Half and Half'],
#  739022: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Scoops! Tortilla Chips',
#   'Peach,  Apricot & Banana Stage 2 Baby Food',
#   'Extra Butter Popcorn',
#   'Fresh Ground Turkey Breast',
#   'Fully Cooked Turkey Sausage Patties',
#   'No More Tears Hand and Face Wipes'],
#  747775: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  763067: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Yellow Bell Pepper'],
#  787916: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   '100% Recycled Bathroom Tissue'],
#  809611: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Hampshire 100% Natural Sour Cream'],
#  812827: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Celery Hearts',
#   'Organic Lemon',
#   'Sparkling Water',
#   'Organic Fancy Shredded Mozzarella Cheese',
#   'Garnet Sweet Potato (Yam)',
#   'Kidz All Natural Baked Chicken Nuggets',
#   'Wild Albacore Tuna No Salt Added',
#   'Old Style Whole Grain Dijon Mustard'],
#  850681: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Pure Coconut Water',
#   'Peanut Butter Bar',
#   'Organic Chicken Broth',
#   'Bing Cherries'],
#  883854: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Italian Extra Virgin Olive Oil',
#   'Yellow Onions'],
#  912431: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Snacks Mango',
#   'Organic Oven Toasted Oats Old Fashioned'],
#  945580: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Sparkling Water',
#   'Gluten Free Tapioca Pudding'],
#  958982: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  984899: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Whole Grassmilk Milk',
#   'Whole Milk',
#   'Cuties Non Dairy Vanilla Frozen Dessert Sandwiches',
#   'Mango Sorbet Pops',
#   'Vanilla Almond Coffee Creamer',
#   "Just Strawberries 'N Bananas"],
#  995322: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Watermelon Chunks',
#   'Gluten Free Multi Seed Rice Thin Crackers'],
#  995649: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Broccoli Crown',
#   'Bosc Pear',
#   'Cauliflower',
#   'Yellow Onions',
#   'Black Beans Reduced Sodium'],
#  999068: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  999426: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  1033471: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Celery Hearts',
#   'Organic Lemon',
#   'Small Hass Avocado',
#   'Organic Salted Butter',
#   'Organic Broccoli',
#   'Homestyle Savory Chicken Bone Broth',
#   'Organic Chicken with Lemongrass Bone Broth',
#   'Blueberry & Purple Sweet Potato  Super Puffs',
#   'Unprocessed American Singles Colby-Style Cheese'],
#  1048369: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Pizza Poppers, Three Cheese',
#   'Instant Coffee',
#   'Organic Honey Mustard',
#   'Organic Bunny Butter Parmesan Pasta'],
#  1073470: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Whole Grassmilk Milk',
#   'Whole Milk Plain Yogurt',
#   'Whole Wheat Tandoori Naan'],
#  1080121: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Pinto Beans No Salt Added',
#   '100% Raw Coconut Water',
#   'Organic Chicken & Apple Sausage',
#   'Tomatillo Salsa',
#   'Gluten Free Multi Seed Rice Thin Crackers'],
#  1083650: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Broccoli Crown',
#   '100% Recycled Paper Towels',
#   'Purity Farms Ghee Clarified Butter'],
#  1086806: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  1092658: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Plain Non-Fat Greek Yogurt',
#   'Natural Creamy Peanut Butter',
#   'Monterey Jack Cheese',
#   'Organic Apple Raisin & Quinoa Stage 2 Baby Food',
#   'Toll House Dark Chocolate Morsels',
#   'Fish Sticks',
#   '1st Foods Sweet Potatoes'],
#  1096015: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Baked White Cheddar Cheese Puffs',
#   'English Muffins',
#   'Raspberry Preserves',
#   'Garlic Hummus',
#   'Honey Turkey Breast',
#   'Defense Up Cold Pressed Fruit Smoothie',
#   'Freeze Dried Strawberry Slices'],
#  1104263: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Natural Spring Water',
#   'Kidz All Natural Baked Chicken Nuggets',
#   'Baked White Cheddar Cheese Puffs',
#   'Nutritional Yeast Seasoning'],
#  1160601: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Seedless Red Grapes',
#   '2% Reduced Fat DHA Omega-3 Reduced Fat Milk'],
#  1161224: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Small Hass Avocado',
#   'Applewood Smoked Bacon',
#   'Organic Balance Vanilla Bean Milk Protein Shake'],
#  1164874: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   '100% Pure Organic Apple Juice',
#   'Made Good Chocolate Chip Granola Bars',
#   'Organic Sprouted Barley Bread'],
#  1197502: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Apple Honeycrisp Organic',
#   'Diced Butternut Squash'],
#  1204677: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Red Raspberries'],
#  1207554: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Seedless Red Grapes',
#   'Raspberry Dark Chocolate bar'],
#  1311414: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Italian Extra Virgin Olive Oil',
#   'Gluten Free SpongeBob Spinach Littles',
#   'Mini Original Babybel Cheese',
#   'Mighty 4 Sweet Potato, Blueberry, Millet & Greek Yogurt Tots Snack',
#   'Mighty 4 Kale, Strawberry, Amaranth & Greek Yogurt Tots Snack',
#   'Potstickers, Organic, Pork & Vegetable'],
#  1328592: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Baby Spinach',
#   'Small Hass Avocado',
#   'Macaroni Elbows',
#   'Milk, Reduced Fat, 2% Milkfat'],
#  1362813: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Medium Salsa Roja'],
#  1408967: ['Organic 4% Milk Fat Whole Milk Cottage Cheese', 'Tuna Steaks'],
#  1416953: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic 1% Low Fat Milk'],
#  1425911: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  1426828: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Organic Orange Bell Pepper'],
#  1451098: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Total 2% Lowfat Greek Strained Yogurt With Blueberry',
#   'Organic Whole Kernel Sweet Corn No Salt Added',
#   'Organic Uncured Beef Hot Dog'],
#  1465854: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Total 2% Lowfat Greek Strained Yogurt With Blueberry',
#   '2% Reduced Fat DHA Omega-3 Reduced Fat Milk',
#   'Yobaby Organic Plain Yogurt',
#   'Organic Orange Bell Pepper',
#   'Organic Apple & Butternut Squash Baby Food'],
#  1466561: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Broccoli Crown',
#   'Organic Good Seed Bread',
#   'Honeysuckle Hand Soap'],
#  1467709: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Applewood Smoked Bacon',
#   'Dark Chocolate Coconut Almond Bark',
#   'MRS MEYERS   12.5OZ HANDSOAP RHUBAR',
#   'Organic Lightly Salted Butter',
#   'Berries & Cherries Paleo Granola'],
#  1471547: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Broccoli',
#   '100% Recycled Paper Towels',
#   'Yotoddler Organic Pear Spinach Mango Yogurt',
#   'Organic Russet Potato Bag'],
#  1496326: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  1535966: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Organic Genoa Salami',
#   'Gogo Squeez Organic Apple Strawberry Applesauce on the Go',
#   'Mini Cucumbers',
#   'Organic Greek Lowfat Yogurt With Strawberries',
#   '2% Reduced Fat DHA Omega-3 Reduced Fat Milk',
#   'Classic Whipped Cream',
#   'Green Machine',
#   'Chicken Breast Tenders Breaded',
#   'Organic Hearty Garden Vegetable Soup'],
#  1536640: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Baby Spinach',
#   'Yellow Onions',
#   'Diced Butternut Squash',
#   'Mini Original Babybel Cheese',
#   'Hickory Smoked Turkey Breast'],
#  1672368: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Whole Milk Ricotta Cheese',
#   'Organic Ground Flaxseed',
#   'Unsweetened Whole Milk Peach Greek Yogurt'],
#  1685847: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Celery Hearts',
#   'Organic Lemon',
#   'Plain Greek Yogurt',
#   'Organic Chicken & Apple Sausage',
#   'Organic Broccoli Crowns',
#   'Arancita Rossa',
#   'Organic Romaine Leaf',
#   'Mini Original Babybel Cheese',
#   'Organic Raw Organic Kraut',
#   'Pompelmo Sparkling Grapefruit Beverage',
#   'Organic Wheat-Free & Gluten-Free Onion Crackers',
#   'Organic Green Sauerkraut',
#   'Original Croccantini'],
#  1693423: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Red Onion'],
#  1700328: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Broccoli Crowns',
#   'Organic Yellow Zucchini'],
#  1784784: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   '100% Whole Wheat Bread',
#   'Organic Frozen Mango Chunks',
#   'Icelandic Style Cream-Skyr 4% Milkfat Strained Whole-Milk Yogurt Mango',
#   'Organic Raspberry Yogurt',
#   'Kids Berry Probiotic Chewables',
#   'Vitamin D3 Gummies, 1000 IU, Great Wild Berry Taste!'],
#  1818112: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  1838673: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Yellow Onions',
#   'Classic Whipped Cream',
#   'Cheese Ravioli with Sauce Bowls'],
#  1844609: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Thompson Seedless Raisins',
#   'Mini Cucumbers',
#   'Whole Milk',
#   'Organic Bagged Mini Milk Peanut Butter'],
#  1864299: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Whipped Naturally Buttery Spread',
#   'Brownberry Natural Wheat Bread',
#   'Shells & Real Aged Cheddar Macaroni & Cheese',
#   'Mini Crispy Crabless Cakes',
#   'Ancient Grain Blueberry Hemp Granola',
#   "Lightly Seasoned Chick'n Scallopini",
#   'Organic Diced Fire Roasted No Salt Added Tomatoes',
#   "Artisan Chick'n & Apple Sausage"],
#  1874211: ['Organic 4% Milk Fat Whole Milk Cottage Cheese', 'Mango Chunks'],
#  1904854: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Mountain Spring Water',
#   'Kitchen Scrubber Sponge'],
#  1984634: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Dairy Free Coconut Milk Chocolate Yogurt Alternative',
#   'Cream Top Smooth & Creamy Plain Yogurt'],
#  2035104: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Light Semisoft Cheese',
#   'Bing Cherries',
#   'Monterey Jack Cheese',
#   'Organic Roasted Garlic Mushroom Lentil Soup'],
#  2051573: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Little Big Sprouted Grain Bread'],
#  2093311: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Diced Tomatoes'],
#  2122538: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Small Hass Avocado'],
#  2134172: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Whole Grassmilk Milk',
#   'English Seedless Cucumber',
#   'Organic Uncured Beef Hot Dog'],
#  2135811: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Large Alfresco Eggs',
#   'Organic Red Onion',
#   'Passion Herbal Infusion Caffeine Free Tea Bags',
#   'Stage 1 Apples Sweet Potatoes Pumpkin & Blueberries Organic Pureed Baby Food',
#   'Nutritional Yeast Seasoning',
#   'Uncured Beef Hot Dogs',
#   'Organic Tangellos'],
#  2141488: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Red Bell Pepper',
#   'Tomato Ketchup',
#   'Gluten-Free Chicken Nuggets',
#   'Organic Creamy Tomato Basil Soup'],
#  2176024: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'European Cucumber',
#   'Little Big Sprouted Grain Bread'],
#  2215509: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Geranium Liquid Dish Soap',
#   'Apple Honeycrisp Organic',
#   'Plain Greek Yogurt',
#   'Organic Milk',
#   'Organic Navel Orange',
#   'Peanut Butter Bar',
#   'Black Tea Pyramids',
#   'Peppermint'],
#  2264496: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Hass Avocados',
#   'Organic Red Bell Pepper',
#   '100% Raw Coconut Water',
#   'Organic Broccoli Crowns',
#   'Crushed Tomatoes',
#   'Organic YoKids Very Berry Smoothies',
#   'Organic Sprouted English Muffin',
#   'Organic Purple Kale',
#   'Organic Yellow Zucchini',
#   'Homestyle Savory Chicken Bone Broth',
#   'Butternut Squash Cumin Soup',
#   'Broccoli with Almond Soup'],
#  2299865: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Vanilla Almond Breeze Almond Milk',
#   'Almond Nut & Rice Cracker Snacks',
#   'Seedless Red Grapes',
#   'Gluten Free Whole Grain Bread',
#   'Naturals Balsamic Vinaigrette'],
#  2310164: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Milk',
#   'Whole Grain Loaf'],
#  2335808: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Whole Milk'],
#  2364762: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Broccoli & Apple Stage 2 Baby Food'],
#  2455875: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Country Morning White Bread',
#   'Organic Whole Chocolate Milk'],
#  2476187: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Brown Eggs',
#   'Crunchy Organic Dark Roasted Peanut Butter',
#   'Raspberry Preserves'],
#  2484958: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Plain Greek Yogurt',
#   'Organic Navel Orange',
#   'Tamari Gluten Free Soy Sauce Reduced Sodium',
#   'Banana Bam Bam Paleo Muffins',
#   'Fresh Pressed Virgin Coconut Oil'],
#  2506581: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Medium Brown Eggs',
#   'Organic American Cheese Singles',
#   'Prosciutto',
#   'Organic Chicken & Apple Sausage',
#   'Organic Mini Homestyle Waffles',
#   'Chocolate Peppermint Stick Bar',
#   "S'mores Luna Bar"],
#  2540385: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Baby Spinach',
#   'Chorizo Style'],
#  2547158: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs'],
#  2549790: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic English Cucumber',
#   'Organic Frozen Mango Chunks',
#   'Organic Broccoli'],
#  2554762: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Squeeze Pouch Sour Cream',
#   'Garlic & Fine Herbs Gournay Cheese'],
#  2566803: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Celery Hearts',
#   'Organic & Raw Strawberry Serenity Kombucha'],
#  2591942: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Small Hass Avocado',
#   'Tea Douglas Fir Spring Tip'],
#  2633801: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Plain Greek Yogurt',
#   'Red Cabbage'],
#  2640788: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese'],
#  2646613: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Pasta Joy Ready Organic Brown Rice Pasta Penne',
#   'Unsweetened Vanilla Cashew Milk'],
#  2704966: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Original Hommus',
#   'Whole Milk Ricotta Cheese',
#   'Blueberry Muffin Bar',
#   'Cheddar Puffs',
#   'Maple Pumpkin Seeds with Sea Salt Chewy with a Crunch Granola Bars',
#   'Organic Cheddar Squares',
#   'Organic Nuts & Vanilla Beverage'],
#  2711771: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Corn Thins, Original',
#   'Kiwi Spinach Peas & Green Apple'],
#  2763636: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Whole Grassmilk Milk',
#   'Broccoli Crown',
#   'Turkey Bar, Almond + Cranberry'],
#  2770555: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'English Seedless Cucumber',
#   'Organic Whole Milk Plain Kefir',
#   'Low Sodium Refried Black Beans',
#   'Spinach & Roasted Garlic Crackers'],
#  2788401: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Organic Good Seed Bread',
#   'Humboldt Fog',
#   'Organic Italian Dressing',
#   'Organic Cream Of Chicken Condensed Soup'],
#  2789939: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Organic Red Bell Pepper',
#   'Apple Honeycrisp Organic',
#   'Organic Red Onion',
#   'Organic Broccoli'],
#  2838740: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   '100% Whole Wheat Bread',
#   'Broccoli Crown',
#   'Seedless Red Grapes',
#   'Gluten Free SpongeBob Spinach Littles',
#   'Organic Sweet Corn',
#   'Organic Berry Basket Blend',
#   'Direct Trade El Diablo Dark Roast Whole Bean Coffee'],
#  2841082: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Vanilla Almond Breeze Almond Milk',
#   '100% Recycled Paper Towels',
#   '2% Reduced Fat DHA Omega-3 Reduced Fat Milk',
#   'First Prunes'],
#  2866129: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Red Bell Pepper',
#   'Organic Broccoli',
#   '100% Recycled Bathroom Tissue'],
#  2895978: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Celery Hearts',
#   'Red Raspberries',
#   'Organic Whole Milk Plain Kefir',
#   'Organic Pure 85% Dark Chocolate Bar',
#   'Whole Grain Loaf',
#   '70% Dark Chocolate With Orange Bar',
#   'Dishwasher Gel Free & Clear'],
#  2974142: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Whole Milk Plain Yogurt',
#   'Whole Milk Ricotta Cheese',
#   'Organic Broccoli',
#   'Trilogy Kombucha',
#   'Yobaby Organic Plain Yogurt'],
#  2997017: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Whole Milk Plain Yogurt',
#   'Wild Berry Smoothie',
#   'Cuties Non Dairy Vanilla Frozen Dessert Sandwiches',
#   'Black Chia Seeds'],
#  3069692: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   '100% Recycled Paper Towels',
#   'Oh My Yog! Madagascar Vanilla Trilayer Yogyurt'],
#  3069893: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Seedless Red Grapes',
#   'Green Peas No Salt Added',
#   'Frozen Peaches'],
#  3078671: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Large Alfresco Eggs',
#   'Mint Chip',
#   'Apricot'],
#  3087122: ['Organic 4% Milk Fat Whole Milk Cottage Cheese', 'Red Raspberries'],
#  3192384: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Blueberries',
#   'Organic Red Bell Pepper',
#   'Lime',
#   'Cottonelle Fresh Care Flushable Cleansing Cloths',
#   'Banana Nut Bread Energy Bar',
#   'Traditional Hot & Spicy Jamaican Jerk Seasoning'],
#  3245375: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  3257274: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Salted Butter',
#   'Organic Broccoli',
#   'No Pulp Calcium & Vitamin D Pure Orange Juice',
#   'Green Onions',
#   'Vanilla Almond Breeze',
#   'Monterey Jack Cheese',
#   'Organic Vegetable Broth'],
#  3267259: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Frozen Mango Chunks',
#   'Herb Crackers',
#   'Frozen Peaches'],
#  3271043: ['Organic 4% Milk Fat Whole Milk Cottage Cheese'],
#  3292791: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Small Hass Avocado',
#   'Sustainably Soft Bath Tissue',
#   'Organic SprouTofu Silken Tofu',
#   'Yellow Onions',
#   'Organic SprouTofu Savory Baked Tofu',
#   'Shells & Real Aged Cheddar Macaroni & Cheese'],
#  3350815: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Organic Lemon',
#   'Baby Spinach'],
#  3387069: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Shredded Parmesan',
#   '100% Raw Coconut Water',
#   'Organic Broccoli',
#   'Traditional Plain Greek Yogurt',
#   'Honey Yoghurt',
#   'Traditionally Crafted Soba Pasta'],
#  3414087: ['Organic 4% Milk Fat Whole Milk Cottage Cheese',
#   'Italian Sparkling Mineral Water'],
#  3418547: ['Organic 4% Milk Fat Whole Milk Cottage Cheese', 'Organic Lemon'],
#  2869: ['Organic Celery Hearts',
#   'Organic Whole Wheat Elbows',
#   'Low Sodium Beef Broth'],
#  3378: ['Organic Celery Hearts',
#   '100% Whole Wheat Bread',
#   'Seedless Red Grapes',
#   'Plain Greek Yogurt',
#   "Simply Venus Pink Women's Disposable Razor",
#   'Natural Creamy Peanut Butter',
#   'Chopped Kale',
#   'Olive Oil & Vinegar Dressing',
#   'Cheerios Cereal'],
#  14119: ['Organic Celery Hearts', 'Organic Red Onion'],
#  17152: ['Organic Celery Hearts',
#   '100% Whole Wheat Bread',
#   'Basil Pesto',
#   'Organic Broccoli'],
#  18271: ['Organic Celery Hearts',
#   'Blueberries',
#   'Mini Original Babybel Cheese',
#   "Berries 'n Cherries Fruit Snacks",
#   'Sandwich Potato Bread',
#   '2-Ply Everyday Napkins'],
#  19552: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Organic Good Seed Bread',
#   'Corn Chips',
#   'Peppered Turkey Breast',
#   'Organic Roasted Red Pepper & Tomato Bisque'],
#  20632: ['Organic Celery Hearts',
#   'Apple Honeycrisp Organic',
#   'Baby Mum-Mum Organic Rice Rusks Original',
#   'Yobaby Organic Plain Yogurt'],
#  22596: ['Organic Celery Hearts'],
#  23669: ['Organic Celery Hearts'],
#  28841: ['Organic Celery Hearts',
#   'Florida Orange Juice With Calcium & Vitamin D',
#   'Rosemary Mini Croccantini'],
#  30009: ['Organic Celery Hearts'],
#  30069: ['Organic Celery Hearts',
#   'Organic Broccoli Crowns',
#   'Soft Pretzel Burger Buns',
#   'Organic Sloppy Joe Seasoning'],
#  32361: ['Organic Celery Hearts',
#   'Organic Yellow Onions',
#   'Organic Teriyaki Seaweed'],
#  33622: ['Organic Celery Hearts',
#   'Organic Red Onion',
#   'Italian Extra Virgin Olive Oil',
#   'Yellow Onions',
#   'Garlic Powder',
#   'Organic Crushed Red Pepper'],
#  35235: ['Organic Celery Hearts',
#   'Organic Good Seed Bread',
#   'Spinach Hummus',
#   'Peanut Butter'],
#  43194: ['Organic Celery Hearts',
#   'Large Alfresco Eggs',
#   '100% Raw Coconut Water',
#   'Spicy Pickle Spears',
#   'Vegan White Napa Cabbage',
#   'Cabbage, Napa, Table Cut',
#   'Organic Raw Organic Kraut',
#   'Classic Meatless Meatballs'],
#  44972: ['Organic Celery Hearts'],
#  53395: ['Organic Celery Hearts',
#   'Broccoli Crown',
#   'Medium Cheddar Cheese Block',
#   'Green Onions',
#   'Organic Cottage Cheese',
#   'Broccoli Rabe',
#   'Mache Blend',
#   'Organic Four Bean Feast Baby Food'],
#  56661: ['Organic Celery Hearts', 'Uncured Sliced Pastrami'],
#  57105: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Gogo Squeez Organic Apple Strawberry Applesauce on the Go',
#   'Organic Red Onion'],
#  57650: ['Organic Celery Hearts',
#   'Natural Spring Water',
#   'Sustainably Soft Bath Tissue',
#   'Organic Chicken Broth',
#   'Organic Turmeric'],
#  57969: ['Organic Celery Hearts', 'Organic Lemon'],
#  58309: ['Organic Celery Hearts',
#   'Vanilla Almond Breeze Almond Milk',
#   'Tomato Ketchup',
#   'Yellow Onions',
#   'Boneless Skinless Chicken Thighs',
#   'Organic Tarragon'],
#  58692: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Ginger Ale Jamaican Style',
#   'Vegan Hickory & Sage Benevolent Bacon'],
#  73280: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Hass Avocados',
#   'Traditional Refried Beans'],
#  74103: ['Organic Celery Hearts',
#   'Cheese Pizza',
#   'Gogo Squeez Organic Apple Strawberry Applesauce on the Go',
#   'Mountain Spring Water',
#   'Himalayan Fine Pink Salt',
#   'Country Morning White Bread',
#   'Organic Chicken & Mozzarella Ravioli',
#   'Organic Mint Mélange Herbal Tea'],
#  75339: ['Organic Celery Hearts',
#   'Baby Cucumbers',
#   'Bag of Large Lemons',
#   'Chocolate Sandwich Cookies',
#   'Imported Italian Peeled Tomatoes'],
#  77034: ['Organic Celery Hearts',
#   'Russet Potato',
#   'Diced Tomatoes',
#   'Green Tea With Ginseng and Honey',
#   '100% Oatnut Bread'],
#  80489: ['Organic Celery Hearts',
#   'Organic Broccoli',
#   'Mini Original Babybel Cheese',
#   'Three Cheese Mini Pizza Bagels Frozen Snacks'],
#  82890: ['Organic Celery Hearts'],
#  83612: ['Organic Celery Hearts', 'Clementines'],
#  83849: ['Organic Celery Hearts'],
#  84509: ['Organic Celery Hearts',
#   'Shells & Real Aged Cheddar Macaroni & Cheese'],
#  84713: ['Organic Celery Hearts',
#   'English Seedless Cucumber',
#   'Organic Chicken Broth',
#   'Monterey Jack Cheese'],
#  87289: ['Organic Celery Hearts',
#   'VitaminWater Zero™ XXX Acai Blueberry Pomegranate',
#   'Revive Zero Vitamin Water'],
#  92892: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Dressing, Jersey Sweet Onion, Calorie Free'],
#  99690: ['Organic Celery Hearts'],
#  108042: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Organic Yokids Lemonade/Blueberry Variety Pack Yogurt Squeezers Tubes'],
#  113486: ['Organic Celery Hearts',
#   'Frozen Organic Blueberries',
#   'Organic Granny Smith Apple Bag'],
#  122499: ['Organic Celery Hearts',
#   'Organic Raw Unfiltered Apple Cider Vinegar',
#   'Granny Smith Apples',
#   'Organic Red Onion',
#   'Cayenne Pepper'],
#  126300: ['Organic Celery Hearts',
#   'Large Alfresco Eggs',
#   'Organic Thompson Seedless Raisins',
#   'Thin Rice Noodles'],
#  127343: ['Organic Celery Hearts',
#   'Organic Chicken & Apple Sausage',
#   'Organic Broccoli',
#   'Unsweetened Organic Coconut Milk',
#   'Cornichons',
#   'Organic Mozzarella'],
#  127980: ['Organic Celery Hearts', 'Black Plum', 'Broccoli Pancakes'],
#  129002: ['Organic Celery Hearts', 'Watermelon Chunks'],
#  129325: ['Organic Celery Hearts',
#   'Organic Broccoli Crowns',
#   'Organic Romaine Leaf'],
#  131931: ['Organic Celery Hearts',
#   'Cantaloupe',
#   'Brown Eggs',
#   'Organic Tomato Paste',
#   'Country Morning White Bread',
#   'Yobaby Organic Plain Yogurt',
#   'Organic Apple & Butternut Squash Baby Food',
#   'Organic Vegetable Lentil & Roasted Red Pepper Soup'],
#  134443: ['Organic Celery Hearts',
#   'Whole Kernel Corn Golden Sweet',
#   'Hearts Of Palm',
#   'Nectarines'],
#  138718: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Small Hass Avocado',
#   'Spinach Pizza',
#   'English Seedless Cucumber',
#   'Organic Milk',
#   'Naturals Chicken Nuggets',
#   'Organic Promise Strawberry Fields Cereal',
#   'Tofu Miso Ramen'],
#  139859: ['Organic Celery Hearts', 'Organic Broccoli'],
#  141857: ['Organic Celery Hearts',
#   'Garnet Sweet Potato (Yam)',
#   'Peanut Butter Creamy With Salt'],
#  143716: ['Organic Celery Hearts',
#   'Organic Whipped Naturally Buttery Spread',
#   'Basil',
#   'Organic Eggplant',
#   'Organic Vegetable Broth',
#   'Organic Vidalia Onion'],
#  148866: ['Organic Celery Hearts',
#   'Cheese Pizza',
#   'Organic Vanilla Soymilk',
#   'Vanilla Soy Creamer'],
#  149851: ['Organic Celery Hearts',
#   'Organic Diced Tomatoes',
#   'Thin Rice Noodles',
#   'Unsweetened Coconut Milk'],
#  153408: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Seedless Red Grapes',
#   'Meyer Lemons'],
#  158134: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Diced Tomatoes',
#   'Organic Frozen Mango Chunks',
#   'Bengal Spice Herbal Tea'],
#  159070: ['Organic Celery Hearts'],
#  161714: ['Organic Celery Hearts',
#   'Organic Broccoli Crowns',
#   'Organic Navel Orange',
#   'Organic Iceberg Lettuce',
#   'Organic Turmeric',
#   'Organic Vanilla Extract'],
#  164723: ['Organic Celery Hearts', 'Duck Eggs'],
#  178513: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Large Alfresco Eggs',
#   'Applewood Smoked Bacon',
#   'Sparkling Water',
#   'Watermelon Chunks',
#   'Organic Elbows & Creamy Mild Cheddar Sauce Creamy Deluxe Macaroni Dinner',
#   'Low Sodium Beef Broth',
#   'Parsley, Italian (Flat), New England Grown',
#   'Organic Shells & White Cheddar Macaroni and Cheese',
#   'Organic Navel Orange',
#   'Havarti Cheese',
#   'Asparagus Spears',
#   'Organic Creamy Tomato Basil Soup',
#   'Organic Lightly Salted Sea Salt Thin & Crispy Restaurant Style Tortilla Chips',
#   'Organic Rosemary Potato Chowder',
#   'Family Size Shells & White Cheddar Macaroni & Cheese',
#   'Blueberry Cinnamon Bread'],
#  181697: ['Organic Celery Hearts'],
#  184838: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Organic Orange Bell Pepper',
#   'The \\"World\'s Best\\" Veggie Burger',
#   'Peanut Butter Chocolate Chip Macrobar',
#   'Organic Herb Blend'],
#  186472: ['Organic Celery Hearts',
#   'Fresh Whole Chicken',
#   'Organic Whole Grain Spanish Rice'],
#  196261: ['Organic Celery Hearts',
#   'Organic Sage',
#   'Organic Mini Homestyle Waffles',
#   'Ice Cream, Super Premium, Mint Chocolate Chip',
#   'Mushroom, Spinach, and Salsa Tamales',
#   'Breadstick',
#   'Organic Plain Unsweetened Nondairy Cashew Yogurt'],
#  197937: ['Organic Celery Hearts', 'Makeup Remover Cleansing Towelettes'],
#  202566: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Organic Diced Tomatoes',
#   'Organic Sprouted English Muffin'],
#  203202: ['Organic Celery Hearts',
#   'Baby Spinach',
#   'Organic Red Onion',
#   'Free & Clear Unscented Refill Value Packs Baby Wipes',
#   "Shepherd's Pie"],
#  204051: ['Organic Celery Hearts',
#   'Yellow Onions',
#   'Organic Purple Kale',
#   'Milk, Reduced Fat, 2% Milkfat',
#   'Organic Red Kidney Beans',
#   'Fresh Ciliegine Mozzarella Cheese'],
#  204137: ['Organic Celery Hearts',
#   'Organic Honey Sweet Whole Wheat Bread',
#   'Total 2% Lowfat Greek Strained Yogurt With Blueberry',
#   'Organic Purple Kale',
#   'Organic Orange Bell Pepper'],
#  208777: ['Organic Celery Hearts',
#   'Organic Butterhead (Boston, Butter, Bibb) Lettuce'],
#  214631: ['Organic Celery Hearts',
#   'Apple Honeycrisp Organic',
#   'Plain Greek Yogurt',
#   'Organic Greek Lowfat Yogurt With Strawberries',
#   'Spicy Avocado Hummus',
#   'Raw Cacao Powder',
#   'Whole Grain Loaf',
#   'Organic Grade A Raw Honey'],
#  216322: ['Organic Celery Hearts', 'Watermelon Chunks'],
#  218591: ['Organic Celery Hearts',
#   'Small Hass Avocado',
#   'Reduced Fat Milk',
#   'Yellow Bell Pepper',
#   'Watermelon Agave Frozen Pops',
#   'Frozen Desserts, Cookies and Cream'],
#  218991: ['Organic Celery Hearts',
#   'Organic Diced Tomatoes',
#   'Heavy Cream',
#   '100% Recycled Aluminum Foil'],
#  225335: ['Organic Celery Hearts',
#   'Organic 2% Buttermilk',
#   'Organic Lemon',
#   'Organic Red Bell Pepper',
#   'Small Hass Avocado',
#   'Organic Red Onion',
#   'Plain Greek Yogurt',
#   'Organic Milk',
#   'Unsalted Pure Irish Butter',
#   'Yellow Onions',
#   'Sliced Tamed Jalapeno Peppers',
#   'French Feta'],
#  225830: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Organic Navel Orange',
#   'Unsweetened Coconut Milk Beverage',
#   '100% Organic Diced Tomatoes'],
#  236867: ['Organic Celery Hearts',
#   'Gluten Free SpongeBob Spinach Littles',
#   'Organic Whole Kernel Sweet Corn No Salt Added',
#   'Feta Cheese',
#   'Mellow White Miso',
#   'Clean Day Liquid Hand Soap Refill Basil Scent'],
#  241789: ['Organic Celery Hearts',
#   'Organic Red Palm & Coconut Shortening',
#   'Old Fashioned Sourdough Spelt Bread',
#   'Medium Salsa Con Queso'],
#  242990: ['Organic Celery Hearts',
#   'House Blend Medium Dark Roast Ground Coffee'],
#  245864: ['Organic Celery Hearts',
#   'Broccoli Crown',
#   'Seedless Red Grapes',
#   'Organic No Salt Added Diced Tomatoes',
#   'English Seedless Cucumber',
#   'Yellow Bell Pepper',
#   'Semi-Sweet Chocolate Premium Baking Chips',
#   'Gluten Free Dark Chocolate Chunk Chewy with a Crunch Granola Bars'],
#  251773: ['Organic Celery Hearts',
#   'Baby Spinach',
#   'Broccoli Crown',
#   'Fresh Whole Chicken'],
#  253246: ['Organic Celery Hearts',
#   'Organic Red Onion',
#   'Sparkling Pomegranate',
#   '100% Recycled Paper Towels',
#   'Organic Whipped Naturally Buttery Spread',
#   'Purple Cauliflower'],
#  255087: ['Organic Celery Hearts',
#   'Raisin Bran Cereal',
#   'Tomato Ketchup',
#   'Organic Whipped Naturally Buttery Spread',
#   'Orignial Recipe Chocolate Pudding',
#   'Natural Gluten-Free Beef Corn Dogs',
#   'Udis Gluten Free Italian Sausage Lasagna'],
#  255114: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Organic Milk',
#   'Garnet Sweet Potato (Yam)'],
#  256718: ['Organic Celery Hearts',
#   'Broccoli Crown',
#   'Taco Seasoning',
#   'Organic Turkey Bacon',
#   'Seedless Red Grapes',
#   '100% Raw Coconut Water',
#   'Whole Milk',
#   'Organic & Raw Strawberry Serenity Kombucha',
#   'Strained Non Fat Orange & Ginger Yogurt',
#   'Freeze Dried Strawberry Slices',
#   'Blueberry Sheep Milk Yogurt',
#   "Organic Whole O's Gluten Free Cereal",
#   'Hickory Smoked Turkey Breast'],
#  259316: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Seedless Red Grapes',
#   'Organic Red Onion',
#   'Organic Fancy Shredded Mozzarella Cheese',
#   'European Cucumber',
#   'Black Tea Variety Pack'],
#  260832: ['Organic Celery Hearts', 'Broccoli Crown'],
#  262777: ['Organic Celery Hearts', 'Hass Avocados', 'Kombucha Green Tea'],
#  265454: ['Organic Celery Hearts',
#   'Natural Spring Water',
#   'Hass Avocados',
#   'Baby Cucumbers',
#   'Key Limes',
#   'Cauliflower Crumbles'],
#  267497: ['Organic Celery Hearts',
#   'Hass Avocados',
#   'Organic Peeled & Cooked Beets',
#   'Tempt Original Hemp Milk',
#   'Organic Deep Greens Kale Blend',
#   'Organic Poblano Pepper'],
#  274329: ['Organic Celery Hearts',
#   'Small Hass Avocado',
#   'Cantaloupe',
#   'Shredded Parmesan',
#   'Multi-Grain Sea Salt Crackers',
#   'Medium Cheddar Cheese Block',
#   'Organic Fresh Basil',
#   'Rosemary Mini Croccantini',
#   'Defense Up Cold Pressed Fruit Smoothie',
#   'Avocado Oil Himalayan Salt Chips',
#   'Revel Berry Yerba Mate'],
#  275022: ['Organic Celery Hearts',
#   'Organic Red Onion',
#   'Organic Whipped Naturally Buttery Spread',
#   'Calcium Enriched 100% Lactose Free Fat Free Milk',
#   'Sweet Potato Tortilla Chips',
#   'Organic Orange Bell Pepper'],
#  280429: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Baby Spinach',
#   'Apple Honeycrisp Organic',
#   'Organic Turkey Bacon',
#   'Organic Honey Sweet Whole Wheat Bread',
#   'Organic Genoa Salami',
#   '100% Raw Coconut Water',
#   '1 Liter',
#   'Organic & Raw Strawberry Serenity Kombucha',
#   'Sliced Genoa Salami',
#   'Wild Sockeye Salmon',
#   'Cumin'],
#  282974: ['Organic Celery Hearts',
#   'Granny Smith Apples',
#   'Organic Red Onion',
#   'Mint',
#   'Wild Rice'],
#  284437: ['Organic Celery Hearts',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Honey Vanilla Greek Yogurt',
#   'Total Plain Greek Strained Yogurt',
#   'Chocolate Chip Cookie Dough Ice Cream',
#   'Naturals Savory Turkey Breakfast Sausage',
#   'Bag of Lemons',
#   'Ultra Plush 3 ply Toilet Paper 12 Double Rolls',
#   'Apple Apple Applesauce On The Go Pouches',
#   'Organic Frozen Blueberries'],
#  286778: ['Organic Celery Hearts',
#   'Broccoli Crown',
#   'Russet Potato',
#   'Boneless Skinless Chicken Breast',
#   'Watermelon Chunks',
#   'Seedless Red Grapes',
#   'Organic Beef Uncured Hot Dogs',
#   'Organic YoKids Very Berry Smoothies',
#   'Feta Cheese',
#   'Green House Grown Miraculously Sweet Tomatoes',
#   'Peperoncini, Greek, Sliced Golden',
#   'Gluten-Free Red Hot Blues Made with Organic Blue  Corn Tortilla Chips',
#   'Organic Fruitful Os Cereal'],
#  296543: ['Organic Celery Hearts',
#   'Vanilla Almond Breeze Almond Milk',
#   'Honey Greek Yogurt'],
#  299877: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Organic Mini Sandwich Crackers Peanut Butter',
#   'All Natural French Toast Sticks',
#   'Vegan Shells & Creamy Sauce Mac & Cheese Macaroni & Cheese Organic',
#   'Organic Kale Pesto Hummus'],
#  305163: ['Organic Celery Hearts',
#   'Whole Almonds',
#   'Organic Broccoli',
#   'Organic Peeled & Cooked Beets',
#   'Organic Romaine Leaf'],
#  309893: ['Organic Celery Hearts',
#   'Organic Red Onion',
#   'Organic Whole Kernel Sweet Corn No Salt Added',
#   'Organic Diced Tomatoes'],
#  314104: ['Organic Celery Hearts',
#   'Clementines',
#   'Brioche Hamburger Buns',
#   'Cauliflower Florets',
#   'Fully Husked & Trimmed Super Sweet Corn',
#   'Ginger Root'],
#  314645: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Creamy Coconut & Peanut Spread',
#   'Dandelion Caramel Nut Herbal Coffee'],
#  315537: ['Organic Celery Hearts',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Yellow Corn Organic Tortillas',
#   'Organic Strawberry Greek Yogurt',
#   'Raspberry Greek Yogurt'],
#  318102: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Broccoli Crown',
#   'Organic Hot Salsa',
#   'Organic Red Onion',
#   'Fresh Whole Chicken',
#   'Yellow Bell Pepper',
#   'Gluten Free Pretzel Sticks',
#   'Organic Acai Berry Smoothie Packs',
#   'Nacho Cheese White Bean Chips',
#   'Artisan Sesame Seeds Nut & Rice Cracker Snacks'],
#  319059: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Seedless Red Grapes',
#   'Organic Navel Orange',
#   'Whole Milk'],
#  323610: ['Organic Celery Hearts', 'Hass Avocados'],
#  324130: ['Organic Celery Hearts',
#   'Naturals Chicken Nuggets',
#   'Salted Caramel Lean Protein & Fiber Bar'],
#  328038: ['Organic Celery Hearts',
#   'Boneless Skinless Chicken Breast',
#   'Unsalted Pure Irish Butter',
#   'Organic Tomato Paste',
#   'Organic YoKids Very Berry Smoothies'],
#  330702: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Organic Red Onion',
#   'Bosc Pear',
#   'Lavender Floral & Mint Natural Dish Liquid',
#   'Boneless Beef Chuck Roast'],
#  332738: ['Organic Celery Hearts'],
#  341729: ['Organic Celery Hearts',
#   'Medium Cheddar Cheese Block',
#   'Sweet Potato Tortilla Chips',
#   'Seasoning, Italian',
#   'Cajun Seasoning'],
#  344189: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Organic Broccoli Crowns',
#   'Seedlander Crispbreads'],
#  345095: ['Organic Celery Hearts',
#   'Original Whole Fat Lactose Free Milk',
#   'Seedless Red Grapes',
#   'Honey Graham Sticks',
#   'Gluten Free Multi Seed Rice Thin Crackers',
#   'Gluten-Free Chicken Nuggets',
#   'Garlic Powder',
#   'Chocolate Peppermint Stick Bar',
#   'Organic Russet Potato Bag',
#   'French Vanilla Almond Granola'],
#  346585: ['Organic Celery Hearts',
#   'Blueberries',
#   'Baby Mum-Mum Organic Rice Rusks Original',
#   'Organic Blueberry Waffles',
#   'Chicken Enchiladas',
#   'Berry Lavendar Ice Cream',
#   'Vegetarian Chili with Beans'],
#  347106: ['Organic Celery Hearts', 'Organic Lemon', 'Organic Red Onion'],
#  347550: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Almondmilk, Pure, Chocolate Protein'],
#  348799: ['Organic Celery Hearts', 'Raw Shrimp', 'Broccoli Florettes'],
#  349890: ['Organic Celery Hearts',
#   'Organic Distilled White Vinegar',
#   'Rutabaga Organic'],
#  353530: ['Organic Celery Hearts', 'Yellow Onions'],
#  355325: ['Organic Celery Hearts'],
#  357137: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Apple Honeycrisp Organic',
#   'Boneless Skinless Chicken Breast',
#   'Dairy Free French Vanilla Creamer Almond Milk',
#   '100% Raw Coconut Water',
#   'Organic Broccoli',
#   'Gluten-Free Supergrain Pasta Organic Corn & Quinoa Blend Penne'],
#  358267: ['Organic Celery Hearts',
#   'Cookie Dough Ice Cream Chocolate Chip',
#   'Organic Brussels Sprouts',
#   'Organic Garlic Powder',
#   'Organic Campari Cocktail Tomatoes',
#   'MATZO BALL MIX'],
#  358979: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Plain Greek Yogurt',
#   'Gluten Free Cafe Chicken Noodle Soup',
#   'Organic Broccoli',
#   'Trilogy Kombucha',
#   'Garlic Asiago Brazilian Cheese Bread'],
#  363155: ['Organic Celery Hearts', 'Coconut Breaded Chicken Breast Tenders'],
#  366976: ['Organic Celery Hearts',
#   'Broccoli Crown',
#   'Organic Iceberg Lettuce',
#   'Traditional Hummus',
#   'Organic Skim Milk with DHA Omega-3',
#   'All American Classic Made with Non-GMO Soy Veggie Burgers'],
#  367796: ['Organic Celery Hearts',
#   'Blueberries',
#   'Whole Almonds',
#   'Organic Red Onion',
#   'Unsalted Pure Irish Butter',
#   'Pecorino Romano',
#   'Organic Chicken Broth',
#   'Organic Vanilla Extract',
#   'gelato Coffee Toffee'],
#  375735: ['Organic Celery Hearts',
#   'Large Alfresco Eggs',
#   'Apple Honeycrisp Organic',
#   'Almond Nut & Rice Cracker Snacks',
#   'Organic Vegetable Broth'],
#  376290: ['Organic Celery Hearts'],
#  377805: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Broccoli Crown',
#   'Organic Red Onion',
#   'Purple Cauliflower'],
#  379551: ['Organic Celery Hearts',
#   'Organic Red Onion',
#   'YoBaby Peach Pear Yogurt',
#   'Baked Aged White Cheddar Rice and Corn Puffs',
#   'Classic Almond Snack Pack',
#   'Pasilla Pepper'],
#  384413: ['Organic Celery Hearts', 'Crunchy Rice Rollers'],
#  386932: ['Organic Celery Hearts',
#   'Reduced Fat Milk',
#   'Almond Nut & Rice Cracker Snacks',
#   'Farfalle No. 93',
#   'Organic Russet Potato Bag'],
#  389275: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Vanilla Sandwich Creme Cookies',
#   'Assorted Compostable Flatware',
#   'Organic Lightly Salted Sea Salt Thin & Crispy Restaurant Style Tortilla Chips',
#   'Organic White Bean & Kale Soup, 25% Less Sodium',
#   'Lasagna, Vegetable, with Daiya Cheeze',
#   'Original Herbamare Infused Sea Salt'],
#  392233: ['Organic Celery Hearts'],
#  396173: ['Organic Celery Hearts'],
#  400091: ['Organic Celery Hearts',
#   'Small Hass Avocado',
#   'Organic Acai Berry Smoothie Packs'],
#  401301: ['Organic Celery Hearts',
#   'Hass Avocados',
#   'Organic Orange Bell Pepper'],
#  403721: ['Organic Celery Hearts',
#   'Blueberries',
#   'Traditional Refried Beans',
#   'Organic White Bread Done Right',
#   'Verde Salsa',
#   'Ground Turkey',
#   'Beef Chuck Roast',
#   'Asian Harvest Sliced Water Chestnuts'],
#  404170: ['Organic Celery Hearts',
#   'Boneless Skinless Chicken Thighs',
#   'Vegan Aged White Cheddar Flavor Puffs',
#   'Lasagna, Vegetable, with Daiya Cheeze'],
#  411391: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Total 2% Lowfat Greek Strained Yogurt With Blueberry',
#   'Organic Broccoli',
#   'Organic White Bread Done Right',
#   'Organic Multigrain Waffles',
#   'Ground Turkey'],
#  420820: ['Organic Celery Hearts',
#   'Pure Coconut Water',
#   'Organic Red Onion',
#   'Shredded Parmesan',
#   'Organic Chicken Broth',
#   'Feta Cheese'],
#  432968: ['Organic Celery Hearts', 'Yukon Gold Potatoes 5lb Bag'],
#  440925: ['Organic Celery Hearts',
#   'Apple Honeycrisp Organic',
#   'Shredded Parmesan',
#   'Green Tea With Ginseng and Honey'],
#  443840: ['Organic Celery Hearts', 'Organic Purple Kale'],
#  444377: ['Organic Celery Hearts',
#   'Green Onions',
#   'Chocolate Chip Cookie Dough Ice Cream'],
#  448872: ['Organic Celery Hearts'],
#  450379: ['Organic Celery Hearts',
#   'Natural Spring Water',
#   'YoBaby Peach Pear Yogurt'],
#  453759: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Apple Honeycrisp Organic',
#   'Shredded Parmesan',
#   'Yellow Onions',
#   'Vodka Pasta Sauce',
#   'Organic Diced Tomatoes',
#   'Organic Chicken Broth',
#   'Organic Himalayan Sweetness Popcorn'],
#  455476: ['Organic Celery Hearts', 'Chopped Pecans'],
#  456394: ['Organic Celery Hearts',
#   'Broccoli Crown',
#   'Small Hass Avocado',
#   'Organic Honey Mustard',
#   'Pummelo'],
#  457738: ['Organic Celery Hearts',
#   'Natural Artisan Water',
#   'Dark Chocolate Almond with Sea Salt'],
#  459487: ['Organic Celery Hearts'],
#  462865: ['Organic Celery Hearts', 'Red Raspberries', 'Pacific Kombu'],
#  463633: ['Organic Celery Hearts',
#   'Small Hass Avocado',
#   'Seedless Red Grapes',
#   'Yellow Onions',
#   'Turkey Franks',
#   'Chili Powder'],
#  466831: ['Organic Celery Hearts',
#   'Organic Thompson Seedless Raisins',
#   'Raisin Bran Cereal',
#   'Whole Milk Ricotta Cheese',
#   'Organic 85% Cacao Dark Chocolate Bar'],
#  469192: ['Organic Celery Hearts',
#   'Organic No Salt Added Diced Tomatoes',
#   'Yellow Onions',
#   'White Cheddar Popcorn'],
#  477144: ['Organic Celery Hearts',
#   'Milk Chocolate Almond Bar',
#   '34% Cacao Milk Chocolate Bar',
#   'Honeysuckle Liquid Soap for Hand & Body'],
#  478112: ['Organic Celery Hearts',
#   'Organic Raw Unfiltered Apple Cider Vinegar',
#   'Organic Red Bell Pepper',
#   'Seedless Red Grapes',
#   'English Seedless Cucumber',
#   'Organic Romaine Leaf',
#   '100% Florida Orange Juice'],
#  478137: ['Organic Celery Hearts',
#   'English Seedless Cucumber',
#   'French Vanilla Ice Cream'],
#  481137: ['Organic Celery Hearts',
# ...
#   'Lavender Hand Soap',
#   'Green Peas No Salt Added'],
#  2556940: ['Organic Celery Hearts',
#   'Apple Honeycrisp Organic',
#   'Seedless Red Grapes',
#   'Organic Red Onion',
#   'Pizza Poppers, Three Cheese',
#   'Honey & Maple Turkey Breast',
#   '2% Reduced Fat DHA Omega-3 Reduced Fat Milk',
#   'Humboldt Fog',
#   'Mexican Finely Shredded Cheese'],
#  2557433: ['Organic Celery Hearts',
#   'Organic Raw Unfiltered Apple Cider Vinegar',
#   'Unsalted Pure Irish Butter',
#   'Petite Brussels Sprouts'],
#  2562200: ['Organic Celery Hearts',
#   'Petit Suisse Fruit',
#   'Organic Tomato Paste'],
#  2562925: ['Organic Celery Hearts',
#   'Baby Spinach',
#   'Italian Sparkling Mineral Water',
#   'Italian Pasta Sauce Puttanesca Tomato & Sliced Olives',
#   'Spaghetti No 3'],
#  2571006: ['Organic Celery Hearts',
#   '100% Raw Coconut Water',
#   'Bag of Lemons',
#   'Serrano Peppers',
#   'Decaf-Zero Green Tea With Ginseng',
#   'NasaFlo Neti Pot Sinus Relief with Premixed',
#   'Liquid Stevia Extract Sweetener'],
#  2574447: ['Organic Celery Hearts',
#   'Organic No Salt Added Diced Tomatoes',
#   'Shredded Parmesan',
#   'Crushed Tomatoes',
#   'Organic Tomato Paste',
#   'Garlic Pepper Ramen',
#   'Coconut Aminos Teriyaki Sauce'],
#  2575586: ['Organic Celery Hearts',
#   'Large Alfresco Eggs',
#   'Mango Chunks',
#   'Pineapple',
#   'Organic Red Cherry Tomato',
#   'Sport Plant-Based Vanilla Flavor Performance Protein Drink Mix'],
#  2577312: ['Organic Celery Hearts', 'The \\"World\'s Best\\" Veggie Burger'],
#  2583012: ['Organic Celery Hearts', 'Classic Coleslaw Salad'],
#  2589672: ['Organic Celery Hearts',
#   'Mint',
#   'European Cucumber',
#   'Lime',
#   'Organic Green Onions',
#   'Traditional Plain Greek Yogurt',
#   'Napa Cabbage',
#   'Unsweetened Coconut Milk',
#   'Coconut Milk Creamer Barista Style Original'],
#  2590741: ['Organic Celery Hearts',
#   'Pure Coconut Water',
#   'Seedless Red Grapes',
#   'Cantaloupe',
#   'Raspberry Preserves',
#   'Pure Coconut Milk'],
#  2591821: ['Organic Celery Hearts',
#   'Watermelon Chunks',
#   'Seedless Red Grapes',
#   'Organic Iceberg Lettuce',
#   'Apricots'],
#  2594485: ['Organic Celery Hearts',
#   'Baby Mum-Mum Organic Rice Rusks Original',
#   'Orange Blossom Water',
#   'Tender Care Diapers Jumbo Pack - Size 4'],
#  2598678: ['Organic Celery Hearts',
#   'Broccoli Crown',
#   'Natural Artesian Bottled Water'],
#  2599750: ['Organic Celery Hearts',
#   'Large Alfresco Eggs',
#   'Organic Red Bell Pepper',
#   'Sea Salt Fine Crystals'],
#  2600805: ['Organic Celery Hearts', 'Organic Sage'],
#  2601468: ['Organic Celery Hearts', 'Organic Navel Orange'],
#  2610040: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Organic Original Hommus',
#   '100% Raw Coconut Water',
#   'Sugarfree Spearmint Chewing Gum',
#   'Organic Mint Dark Chocolate Bar',
#   'Sandwich Resealable Bags',
#   'Cinnamon Gum'],
#  2610387: ['Organic Celery Hearts',
#   'Honey Vanilla Greek Yogurt',
#   'Olive Oil & Vinegar Dressing',
#   'Naturals Chicken Nuggets',
#   'Organic Shredded Mild Cheddar',
#   'Organic Orange Bell Pepper'],
#  2614217: ['Organic Celery Hearts',
#   'Organic Red Onion',
#   'Tilapia Filet',
#   "Builder's® Chocolate Peanut Butter Protein Bars",
#   'Ciabatta Bread'],
#  2614366: ['Organic Celery Hearts',
#   'Yellow Corn Organic Tortillas',
#   'Teriyaki Chicken Bowl'],
#  2617265: ['Organic Celery Hearts', 'Hass Avocados'],
#  2617766: ['Organic Celery Hearts',
#   'Organic No Salt Added Diced Tomatoes',
#   'Traditional Hummus',
#   'Peppered Turkey Breast'],
#  2619638: ['Organic Celery Hearts',
#   'Vanilla Almond Breeze Almond Milk',
#   'Seedless Red Grapes',
#   'Organic Red Onion'],
#  2629165: ['Organic Celery Hearts', 'Gluten Free Mushroom Risotto Bowl'],
#  2629779: ['Organic Celery Hearts',
#   'Granny Smith Apples',
#   'Diced Tomatoes',
#   'Organic Thompson Seedless Raisins',
#   'Seedless Red Grapes',
#   'Cantaloupe',
#   'Bosc Pear',
#   'Yellow Bell Pepper'],
#  2630780: ['Organic Celery Hearts', '100% Raw Coconut Water'],
#  2632390: ['Organic Celery Hearts',
#   'Organic Whole Grassmilk Milk',
#   'Organic Lemon',
#   'Large Alfresco Eggs',
#   'Organic Original Hommus',
#   'Organic Red Onion',
#   '100% Raw Coconut Water',
#   'Frozen Peaches',
#   'Organic Blue Agave'],
#  2636185: ['Organic Celery Hearts',
#   'Apple Honeycrisp Organic',
#   'Organic Red Onion',
#   'Mint',
#   'Organic Broccoli',
#   'White Onion',
#   'Organic Navel Orange',
#   'Wild Arugula Salad'],
#  2636459: ['Organic Celery Hearts',
#   'Organic Carrot Juice',
#   'Organic Russet Potato Bag'],
#  2643097: ['Organic Celery Hearts', 'Pure Coconut Water', 'Yellow Onions'],
#  2644254: ['Organic Celery Hearts',
#   'Organic Whole Wheat Elbows',
#   'Organic No Salt Added Diced Tomatoes',
#   'Organic Chicken Stock'],
#  2650993: ['Organic Celery Hearts'],
#  2652584: ['Organic Celery Hearts',
#   'Clover Org Greek Plain',
#   'Whole Hearts of Palm',
#   'Honey Turkey Breast'],
#  2656855: ['Organic Celery Hearts',
#   'Organic Sage',
#   'Organic Lemon Lowfat Yogurt',
#   'Organic Italian Herb Pasta Sauce',
#   'Organic Garden Vegetable Pasta Sauce',
#   'Organic Navel Orange',
#   'Unsalted Pure Irish Butter',
#   'Organic Raspberry Lowfat Yogurt',
#   'Lowfat Vanilla Yogurt',
#   'Ciabatta Bread',
#   'Garlic & Herb Butter Stick',
#   'Organic Lowfat Creamy Australian Style Orange Passion Fruit Yogurt',
#   'Light Ice Cream Vanilla'],
#  2666153: ['Organic Celery Hearts',
#   'Organic Red Onion',
#   'Trilogy Kombucha',
#   'Organic Purple Kale'],
#  2666849: ['Organic Celery Hearts', 'Wild Pink Salmon'],
#  2667193: ['Organic Celery Hearts', 'Organic SprouTofu Savory Baked Tofu'],
#  2667493: ['Organic Celery Hearts',
#   'Organic Shredded Mild Cheddar',
#   'Tater Puffs',
#   'Whipped Butter'],
#  2677668: ['Organic Celery Hearts',
#   'Golden Maple Sweet Belgian Style Waffles'],
#  2683177: ['Organic Celery Hearts'],
#  2687260: ['Organic Celery Hearts',
#   'Organic No Salt Added Diced Tomatoes',
#   'Organic Red Onion',
#   'Shredded Parmesan',
#   'Cauliflower',
#   'Yellow Onions',
#   'Organic Vegetable Broth',
#   'Dark Red Kidney Beans No Salt Added'],
#  2690463: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Soft Pretzel Burger Buns',
#   'Diced Butternut Squash',
#   'Mighty 4 Sweet Potato, Blueberry, Millet & Greek Yogurt Tots Snack',
#   'Maifun Brown Rice Noodles',
#   'Apple Quinoa Cinnamon Oatmeal Fruit Squeeze',
#   'French Demi Baguette'],
#  2690560: ['Organic Celery Hearts',
#   'Crunchy Peanut Butter',
#   'Baked Aged White Cheddar Rice and Corn Puffs',
#   'Natural Liquid Laundry Detergent - Blue Eucalyptus and Lavender',
#   'Organic Chicken & Wild Rice Soup'],
#  2690791: ['Organic Celery Hearts'],
#  2691084: ['Organic Celery Hearts',
#   'Blueberries',
#   'Prosciutto',
#   'Raspberry Preserves',
#   'Vintage Extra Sharp White Cheddar Cheese'],
#  2695061: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Shells & Real Aged Cheddar Macaroni & Cheese'],
#  2696643: ['Organic Celery Hearts',
#   'Baby Spinach',
#   'Organic Red Onion',
#   'Yellow Onions',
#   'Original Unsweetened Dairy-Free Beverage'],
#  2703181: ['Organic Celery Hearts',
#   'Organic Good Seed Bread',
#   'Lunchables Pizza with Pepperoni',
#   'Organic Deep Greens Kale Blend'],
#  2705139: ['Organic Celery Hearts'],
#  2706556: ['Organic Celery Hearts',
#   'Organic 2% Reduced Fat Milk',
#   'No Pulp Calcium & Vitamin D Pure Orange Juice'],
#  2709723: ['Organic Celery Hearts'],
#  2713402: ['Organic Celery Hearts',
#   'Organic Broccoli Crowns',
#   'Original Unsweetened Dairy-Free Beverage',
#   'Spinach And Ricotta Ravioli',
#   'Baby Mum-Mum Organic Rice Rusks Original',
#   'Mushroom And Ricotta Ravioli'],
#  2717506: ['Organic Celery Hearts',
#   'Cream Of Tartar',
#   'Select-A-Size Paper Towels, White, 2 Huge Rolls = 5 Regular Rolls  Towels/Napkins',
#   'Low Fat Cottage Cheese'],
#  2722107: ['Organic Celery Hearts', 'Organic Red Onion'],
#  2725651: ['Organic Celery Hearts',
#   'Organic Red Onion',
#   'Vanilla Sandwich Creme Cookies',
#   'Peanut Butter Creme Cookies',
#   'Cinnamon Sugar Donut Holes'],
#  2727510: ['Organic Celery Hearts',
#   'Organic Mushroom & Olive Pizza',
#   'Tortilla Chips, Clasico, Bacon Habanero',
#   'Original Coconut Milk Creamer',
#   'Organic Apricots'],
#  2728698: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Large Alfresco Eggs',
#   '100% Raw Coconut Water',
#   'Plain Goat Milk Yogurt',
#   'Unsweetened Vanilla Cashew Milk',
#   'Organic Vanilla Extract',
#   'Grape Sunflower Butter Sunwiches'],
#  2731305: ['Organic Celery Hearts',
#   'Organic Butterhead (Boston, Butter, Bibb) Lettuce',
#   'Yellow Bell Pepper',
#   'Chipotle Pepprs in Adobo Sauce'],
#  2733086: ['Organic Celery Hearts', 'Russet Potato', 'Yellow Onions'],
#  2733264: ['Organic Celery Hearts',
#   'Organic Chocolate Almondmilk Pudding',
#   'Dairy Free Coconut Milk Raspberry Yogurt Alternative',
#   'Pink Lady Apple Kombucha',
#   'European Cucumber',
#   'Italian Sparkling Mineral Water',
#   'Organic Diced Tomatoes',
#   'Mango Chunks',
#   'Organic SprouTofu Savory Baked Tofu',
#   'Organic Red Heirloom Pasta Sauce',
#   'Organic Bagged Kale Salad Mix',
#   'Imported Butter',
#   'Organic Blue Corn Sea Salt Tortilla Chips'],
#  2737435: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Traditional Refried Beans',
#   'Organic White Bread Done Right',
#   'Chicken Marinade, Citrus & Onion',
#   'Santitas White Corn Tortilla Chips',
#   'Classics Meat Lovers Lasagna',
#   'Extra Soft Double Roll Bathroom Tissue',
#   'Antibacterial Kitchen Cleaner Citrus Scent',
#   'Power & Free Multi-Purpose Cleaner',
#   'Tender white meat chicken in a red chile lime sauce with a medley of roasted corn, peppers, and rice Chile Lime Chicken',
#   'Reclosable Snack Bags'],
#  2737490: ['Organic Celery Hearts', 'Mozzarella Cheese'],
#  2739002: ['Organic Celery Hearts',
#   'Large Alfresco Eggs',
#   'Organic Raspberry Lowfat Yogurt',
#   'Cardamom SmartFloss',
#   'Organic Acacia Fiber',
#   'Hemp Vanilla Unsweetened Non-Dairy Beverage',
#   'Ultimate Flora 80 Billion Probiotic Vegetable Capsules'],
#  2739151: ['Organic Celery Hearts',
#   'Original Popcorn',
#   'Club Soda Lower Sodium',
#   'Extra Large Grade A Eggs',
#   'Lemonade Drink Mix'],
#  2749097: ['Organic Celery Hearts',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'Organic Elbows & Creamy Mild Cheddar Sauce Creamy Deluxe Macaroni Dinner',
#   'Shredded Parmesan',
#   'Organic Homestyle Mini Waffles',
#   'Honey & Maple Turkey Breast',
#   'Organic YoKids Very Berry Smoothies',
#   'Traditional Hummus',
#   'Stage 1 Apples Sweet Potatoes Pumpkin & Blueberries Organic Pureed Baby Food',
#   'Apple Blueberry Fruit Yogurt Smoothie',
#   'Broccoli & Apple Stage 2 Baby Food',
#   'Raspberry Preserves'],
#  2754305: ['Organic Celery Hearts', 'Diced Tomatoes', 'Bok Choy'],
#  2756473: ['Organic Celery Hearts',
#   'Watermelon Chunks',
#   'Seedless Red Grapes',
#   'Organic Red Onion',
#   'Natural Classic Pork Breakfast Sausage',
#   'Peppered Turkey Breast'],
#  2756772: ['Organic Celery Hearts',
#   'Organic Diced Tomatoes',
#   'Pancake & Baking Mix',
#   'Frozen Organic Blueberries'],
#  2758538: ['Organic Celery Hearts', 'Organic Romaine Leaf'],
#  2761373: ['Organic Celery Hearts',
#   'Seedless Red Grapes',
#   'Red Raspberries',
#   'Organic Yellow Zucchini',
#   'Organic Bunny Butter Parmesan Pasta',
#   'Dark Chocolate, Firecracker, 60% Cacao'],
#  2763283: ['Organic Celery Hearts',
#   '100% Whole Wheat Bread',
#   'Broccoli Crown',
#   'Organic Red Bell Pepper',
#   'Florida Orange Juice With Calcium & Vitamin D',
#   'Watermelon Chunks',
#   'Almond Nut & Rice Cracker Snacks',
#   'Seedless Red Grapes',
#   'Cantaloupe',
#   'Organic Navel Orange',
#   'Organic Shredded Mild Cheddar',
#   'Organic Braeburn Apple',
#   'Organic Whole Milk French Vanilla Yogurt'],
#  2766170: ['Organic Celery Hearts', 'Organic Lemon'],
#  2767214: ['Organic Celery Hearts',
#   'Mint',
#   'Jalapeno Almond Jack Cheese Alternative'],
#  2774370: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   '100% Raw Coconut Water',
#   'Organic Navel Orange',
#   'Organic Eggplant'],
#  2775649: ['Organic Celery Hearts', 'Seedless Red Grapes'],
#  2776395: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Organic English Cucumber',
#   'Organic Unsalted Butter',
#   'Tilapia Filet',
#   'Organic Yellow Zucchini',
#   'Gluten-Free Supergrain Pasta Elbows',
#   'Roasted Green Chile & Jack Cheese Tamales',
#   'Black Chia Seeds'],
#  2783312: ['Organic Celery Hearts', 'Italian Sparkling Mineral Water'],
#  2788078: ['Organic Celery Hearts',
#   'Black Plum',
#   'Organic Red Bell Pepper',
#   'Organic Turkey Bacon',
#   'Organic Red Onion',
#   'Bing Cherries',
#   'Deluxe Red Raspberry Fruit Spread',
#   'Organic Quick Rolled Oats'],
#  2792510: ['Organic Celery Hearts', 'Large Alfresco Eggs'],
#  2792816: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Yukon Gold Potatoes 5lb Bag',
#   'Organic Salted Butter'],
#  2793593: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Organic Gluten Free Quinoa Spaghetti',
#   'Gluten Free Muffin Mix'],
#  2795721: ['Organic Celery Hearts', 'Broccoli Crown'],
#  2798992: ['Organic Celery Hearts',
#   'Crunchy Organic Dark Roasted Peanut Butter',
#   'Organic Broccoli',
#   'Organic Chicken Broth',
#   "Shepherd's Pie",
#   'Gluten Free Mushroom Risotto Bowl',
#   'Italian Pasta Sauce Puttanesca Tomato & Sliced Olives',
#   'Bread, Watsonville Sourdough'],
#  2799139: ['Organic Celery Hearts',
#   'Clementines',
#   'Hass Avocados',
#   'Packaged Grape Tomatoes'],
#  2799709: ['Organic Celery Hearts', 'Strained Non Fat Orange & Ginger Yogurt'],
#  2801375: ['Organic Celery Hearts',
#   'Organic Navel Orange',
#   'Traditional Hummus'],
#  2803301: ['Organic Celery Hearts', 'Organic Broccoli'],
#  2805183: ['Organic Celery Hearts',
#   '2% Reduced Fat DHA Omega-3 Reduced Fat Milk',
#   'Yotoddler Organic Pear Spinach Mango Yogurt'],
#  2806282: ['Organic Celery Hearts',
#   'Organic Lemon',
#   'Organic Red Bell Pepper',
#   'Small Hass Avocado',
#   'Kombucha Gingerade',
#   'Organic & Raw Strawberry Serenity Kombucha',
#   'Sparkling Probiotic Pomegranate Drink',
#   'Naked Paleo Pizza Crust',
#   'Gluten Free Paleo Fettuccine',
#   'Semi-Sweet Mini Chocolate Chips',
#   'Organic Pomegranate'],
#  2807049: ['Organic Celery Hearts'],
#  2807967: ['Organic Celery Hearts',
#   'Organic Reduced Fat 2% Milk',
#   '100% Raw Coconut Water',
#   'Large Pineapple Chunks',
#   'Toasted Coconut Almondmilk Blend',
#   'Organic Navel Orange',
#   'Organic Peeled & Cooked Beets',
#   'Green Onions',
#   'Organic Flax Plus Multibran Flakes',
#   'Semi-Sweet Mini Chocolate Chips',
#   'English Peas Pack'],
#  2808627: ['Organic Celery Hearts',
#   'Organic Chicken Broth',
#   'Organic Baby Romaine',
#   'Organic Yokids Lemonade/Blueberry Variety Pack Yogurt Squeezers Tubes',
#   'Rosemary Olive Oil Bread'],
#  2810520: ['Organic Celery Hearts',
#   'Organic Chicken Stock',
#   'Peeled Shallots'],
#  2812469: ['Organic Celery Hearts', 'Organic Broccoli'],
#  2812721: ['Organic Celery Hearts'],
#  2813769: ['Organic Celery Hearts',
#   'Organic Red Bell Pepper',
#   'Organic Thompson Seedless Raisins',
#   'Organic Iceberg Lettuce',
#   'Juice Drink, Fruit & Vegetable, Lavenade'],
#  2816103: ['Organic Celery Hearts', 'Organic Lemon', 'Blueberry Muffin Bar'],
#  2827178: ['Organic Celery Hearts',
#   'Shredded Parmesan',
#   'Organic California Style Sprouted Bread',
#   'Organic Brown Rice Crisps Cereal'],
#  2829078: ['Organic Celery Hearts', 'Organic Navel Orange'],
#  2829263: ['Organic Celery Hearts',
#   'Broccoli Crown',
#   'Florida Orange Juice With Calcium & Vitamin D',
#   'Seedless Red Grapes',
#   'Cantaloupe',
#   'Mocha Almond Fudge Minis Almond Milk Frozen Dessert',
#   'Organic Mini Homestyle Waffles',
#   'Semi-Sweet Mini Chocolate Chips'],
#  2846624: ['Organic Celery Hearts',
#   'Organic English Cucumber',
#   'Seedless Red Grapes',
#   'Organic Fancy Shredded Mozzarella Cheese',
#   'Garlic Powder',
#   'Seasoning Paprika'],
#  2847627: ['Organic Celery Hearts',
#   'Cantaloupe',
#   '100% Raw Coconut Water',
#   'Red Raspberries',
#   'Organic Acai Berry Smoothie Packs'],
#  2848311: ['Organic Celery Hearts',
#   'Russet Potato',
#   'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese',
#   'English Seedless Cucumber',
#   'Red Raspberries',
#   'Cauliflower',
#   'YoBaby Peach Pear Yogurt',
#   'Fresh Mozzarella Snacking Cheese',
#   '100% Whole Wheat Pre-Sliced Sandwich Thins',
#   'Chicken Breast Tenders Breaded'],
#  2853455: ['Organic Celery Hearts'],
#  ...}

# %%
text=[]
for i in transactions:
    if len(transactions[i])!=1:
        text.append(";".join(transactions[i]))

# %%
text = "|".join(text)

# %%
def replace(text):
    if ' ' in text: 
        text = text.replace(' ' , '_')
        text = text.replace('-','_')
        text = text.replace(',','_')
    return text
t=replace(text)

# %%
len(transactions)
# Out:
# 105897

# %%
from tensorflow.keras.utils import to_categorical
from keras_preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
import numpy as np

# %%
import pickle
tokenizer = Tokenizer(filters=';|',lower=True)

tokenizer.fit_on_texts([t])
vocabulary_size = len(tokenizer.word_index) + 1
print('Unique items: %d' % vocabulary_size)
sequences = list()
for line in text.split('|'):
    encoded = tokenizer.texts_to_sequences([line])[0]
    encoded=encoded[:5]
    sequences.append(encoded)
print('Total Sequences: %d' % len(sequences))
pickle.dump(tokenizer, open("token.pickle", "wb"))
# Out:
# Unique items: 9518
# Total Sequences: 74268

# %%
tokenizer.word_index
# Out:
# {'seedless_red_grapes': 1,
#  'organic_red_onion': 2,
#  'yellow_onions': 3,
#  'organic_lemon': 4,
#  'small_hass_avocado': 5,
#  'broccoli_crown': 6,
#  'organic_red_bell_pepper': 7,
#  '100%_whole_wheat_bread': 8,
#  'blueberries': 9,
#  'apple_honeycrisp_organic': 10,
#  'hass_avocados': 11,
#  'organic_navel_orange': 12,
#  'large_alfresco_eggs': 13,
#  'organic_broccoli': 14,
#  'organic_reduced_fat_2%_milk': 15,
#  'red_raspberries': 16,
#  'green_onions': 17,
#  'russet_potato': 18,
#  'organic_sticks_low_moisture_part_skim_mozzarella_string_cheese': 19,
#  'shredded_parmesan': 20,
#  'granny_smith_apples': 21,
#  'whole_milk': 22,
#  'cantaloupe': 23,
#  'vanilla_almond_breeze_almond_milk': 24,
#  '100%_raw_coconut_water': 25,
#  'yellow_bell_pepper': 26,
#  'baby_spinach': 27,
#  '100%_recycled_paper_towels': 28,
#  'organic_celery_hearts': 29,
#  'italian_sparkling_mineral_water': 30,
#  'clementines': 31,
#  'boneless_skinless_chicken_breast': 32,
#  'soda': 33,
#  'organic_2%_reduced_fat_milk': 34,
#  'white_onion': 35,
#  'organic_milk': 36,
#  'organic_diced_tomatoes': 37,
#  'watermelon_chunks': 38,
#  'organic_broccoli_crowns': 39,
#  'natural_spring_water': 40,
#  'sustainably_soft_bath_tissue': 41,
#  'english_seedless_cucumber': 42,
#  'mango_chunks': 43,
#  'unsalted_pure_irish_butter': 44,
#  'organic_unsalted_butter': 45,
#  'organic_tomato_paste': 46,
#  'basil_pesto': 47,
#  'pure_coconut_water': 48,
#  'organic_american_cheese_singles': 49,
#  'dressing__jersey_sweet_onion__calorie_free': 50,
#  'original_nooks_&_crannies_english_muffins': 51,
#  'grade_a_large_white_eggs': 52,
#  'diced_tomatoes': 53,
#  'total_2%_lowfat_greek_strained_yogurt_with_blueberry': 54,
#  'european_cucumber': 55,
#  'tomato_ketchup': 56,
#  'organic_turkey_bacon': 57,
#  'raisin_bran_cereal': 58,
#  'organic_whole_kernel_sweet_corn_no_salt_added': 59,
#  'toasted_coconut_almondmilk_blend': 60,
#  'fridge_pack_cola': 61,
#  'organic_iceberg_lettuce': 62,
#  'cauliflower': 63,
#  'italian_extra_virgin_olive_oil': 64,
#  'organic_whipped_naturally_buttery_spread': 65,
#  'mini_original_babybel_cheese': 66,
#  '2%_reduced_fat_dha_omega_3_reduced_fat_milk': 67,
#  'baked_aged_white_cheddar_rice_and_corn_puffs': 68,
#  'packaged_grape_tomatoes': 69,
#  'organic_salted_butter': 70,
#  'green_tea_with_ginseng_and_honey': 71,
#  'whole_milk_plain_yogurt': 72,
#  'baby_cucumbers': 73,
#  'tilapia_filet': 74,
#  'organic_english_cucumber': 75,
#  'organic_thompson_seedless_raisins': 76,
#  'organic_chicken_&_apple_sausage': 77,
#  'organic_orange_bell_pepper': 78,
#  'crushed_tomatoes': 79,
#  'mint': 80,
#  'plain_greek_yogurt': 81,
#  'organic_bunny_fruit_snacks_berry_patch': 82,
#  'gluten_free_whole_grain_bread': 83,
#  'lime': 84,
#  'organic_chicken_stock': 85,
#  'medium_cheddar_cheese_block': 86,
#  'cinnamon_rolls_with_icing': 87,
#  'naturals_chicken_nuggets': 88,
#  'organic_whole_grassmilk_milk': 89,
#  'sparkling_water': 90,
#  'cage_free_large_white_eggs': 91,
#  'organic_chicken_broth': 92,
#  'raspberry_preserves': 93,
#  'whole_almonds': 94,
#  'organic_vegetable_broth': 95,
#  'organic_butterhead_(boston__butter__bibb)_lettuce': 96,
#  'organic_original_hommus': 97,
#  'no_pulp_calcium_&_vitamin_d_pure_orange_juice': 98,
#  'taco_seasoning': 99,
#  'organic_multigrain_waffles': 100,
#  'garlic_&_fine_herbs_gournay_cheese': 101,
#  'dried_mango': 102,
#  'reduced_fat_milk': 103,
#  'organic_good_seed_bread': 104,
#  'scoops!_tortilla_chips': 105,
#  'boneless_skinless_chicken_thighs': 106,
#  'chocolate_chip_cookie_dough_ice_cream': 107,
#  'organic_1%_low_fat_milk': 108,
#  'organic_raw_unfiltered_apple_cider_vinegar': 109,
#  'natural_sharp_cheddar_sliced_cheese': 110,
#  'parsley__italian_(flat)__new_england_grown': 111,
#  'natural_artisan_water': 112,
#  'organic_romaine_leaf': 113,
#  'honey_yoghurt': 114,
#  'mini_cucumbers': 115,
#  'shells_&_real_aged_cheddar_macaroni_&_cheese': 116,
#  'organic_honey_sweet_whole_wheat_bread': 117,
#  'organic_no_salt_added_diced_tomatoes': 118,
#  'broccoli_&_cheddar_bake_meal_bowl': 119,
#  'black_plum': 120,
#  'organic_distilled_white_vinegar': 121,
#  'traditional_hummus': 122,
#  'garlic_hummus': 123,
#  'organic_cream_cheese_bar': 124,
#  'mint_chip': 125,
#  'white_cheddar_popcorn': 126,
#  'gluten_free_dark_chocolate_chunk_chewy_with_a_crunch_granola_bars': 127,
#  'almond_nut_&_rice_cracker_snacks': 128,
#  'organic_frozen_mango_chunks': 129,
#  'nonfat_icelandic_style_strawberry_yogurt': 130,
#  'natural_classic_pork_breakfast_sausage': 131,
#  'whole_milk_ricotta_cheese': 132,
#  'cauliflower_florets': 133,
#  'vanilla_almond_breeze': 134,
#  'margherita_pizza': 135,
#  'chicken_breast_tenders_breaded': 136,
#  'white_corn_tortillas': 137,
#  'kidz_all_natural_baked_chicken_nuggets': 138,
#  'organic_fuji_apples': 139,
#  'basil': 140,
#  'corn_chips': 141,
#  'original_popcorn': 142,
#  'premium_original_saltine_crackers': 143,
#  'organic_vanilla_extract': 144,
#  'butter': 145,
#  'peanut_butter_creamy_with_salt': 146,
#  'organic_simply_naked_pita_chips': 147,
#  'mozzarella_string_cheese': 148,
#  'organic_short_grain_brown_rice': 149,
#  'arancita_rossa': 150,
#  'angel_hair_pasta': 151,
#  'original_fresh_stack_crackers': 152,
#  'broccoli_florettes': 153,
#  'spaghetti__no_12': 154,
#  'garnet_sweet_potato_(yam)': 155,
#  'organic_red_potatoes': 156,
#  'organic_blueberry_waffles': 157,
#  'original_black_box_tablewater_cracker': 158,
#  'organic_purple_kale': 159,
#  'cheese_pizza': 160,
#  'cheerios_cereal': 161,
#  'backyard_barbeque_potato_chips': 162,
#  'organic_cottage_cheese': 163,
#  'organic_original_almond_milk': 164,
#  'unsweetened_coconut_milk_beverage': 165,
#  'honey_greek_yogurt': 166,
#  'yukon_gold_potatoes_5lb_bag': 167,
#  'whole_grain_oat_cereal': 168,
#  'lowfat_vanilla_yogurt': 169,
#  'penne_rigate_#41_pasta': 170,
#  'organic_sprouted_english_muffin': 171,
#  'monterey_jack_cheese': 172,
#  'yobaby_peach_pear_yogurt': 173,
#  'light_semisoft_cheese': 174,
#  'four_cheese_thin_crust_pizza': 175,
#  'organic_peeled_&_cooked_beets': 176,
#  'hazelnut_spread_with_skim_milk_&_cocoa': 177,
#  'florida_orange_juice_with_calcium_&_vitamin_d': 178,
#  'cola_soft_drink': 179,
#  'medium_salsa_roja': 180,
#  'naturals_savory_turkey_breakfast_sausage': 181,
#  'bosc_pear': 182,
#  'garlic_powder': 183,
#  'organic_lightly_salted_sea_salt_thin_&_crispy_restaurant_style_tortilla_chips': 184,
#  'organic_fresh_basil': 185,
#  'organic_yokids_very_berry_smoothies': 186,
#  'organic_greek_lowfat_yogurt_with_strawberries': 187,
#  'strawberry_rhubarb_yogurt': 188,
#  'turkey_bacon': 189,
#  '100%_recycled_bathroom_tissue': 190,
#  'organic_brussels_sprouts': 191,
#  'organic_shredded_mild_cheddar': 192,
#  'organic_lactose_free_1%_lowfat_milk': 193,
#  'organic_genoa_salami': 194,
#  'traditional_favorites_tomato_&_basil_pasta_sauce': 195,
#  'pineapple': 196,
#  'baby_portabella_mushrooms': 197,
#  'bok_choy': 198,
#  'vitamin_water_zero_squeezed_lemonade': 199,
#  'wild_berry_smoothie': 200,
#  'gluten_free_spongebob_spinach_littles': 201,
#  "major_dickason's_blend_ground_coffee_dark_roast": 202,
#  'lavender_hand_soap': 203,
#  'purity_farms_ghee_clarified_butter': 204,
#  'milk__reduced_fat__2%_milkfat': 205,
#  'applewood_smoked_bacon': 206,
#  'uncured_beef_hot_dogs': 207,
#  'organic_mini_sandwich_crackers_peanut_butter': 208,
#  'peanut_butter_ice_cream_cup': 209,
#  'large_pineapple_chunks': 210,
#  'sauvignon_blanc': 211,
#  'peanut_butter_cereal': 212,
#  'yobaby_organic_plain_yogurt': 213,
#  'cinnamon_raisin_bread': 214,
#  'frozen_organic_blueberries': 215,
#  'mozzarella_cheese': 216,
#  '93%_ground_beef': 217,
#  'organic_raw_multigreen_kobmbucha': 218,
#  'traditional_plain_greek_yogurt': 219,
#  'organic_green_onions': 220,
#  'dairy_free_coconut_milk_blueberry_yogurt_alternative': 221,
#  'organic_zucchini_spirals': 222,
#  'organic_russet_potato_bag': 223,
#  'organic_&_raw_strawberry_serenity_kombucha': 224,
#  'soft_pretzel_burger_buns': 225,
#  'organic_braeburn_apple': 226,
#  'sparkling_natural_spring_water': 227,
#  'plain_non_fat_greek_yogurt': 228,
#  'sweet_potato_tortilla_chips': 229,
#  'synergy_organic_&_raw_cosmic_cranberry': 230,
#  'mountain_spring_water': 231,
#  'mexican_style_taco_shredded_cheese': 232,
#  'mexican_finely_shredded_cheese': 233,
#  'crunchy_peanut_butter': 234,
#  'frozen_peaches': 235,
#  'prosciutto': 236,
#  'cut_&_peeled_baby_carrots': 237,
#  'original_syrup': 238,
#  'broccoli_&_apple_stage_2_baby_food': 239,
#  'organic_low_sodium_chicken_cooking_stock': 240,
#  'organic_acai_berry_smoothie_packs': 241,
#  'organic_yokids_lemonade/blueberry_variety_pack_yogurt_squeezers_tubes': 242,
#  'pink_lady_apple_kombucha': 243,
#  'bolthouse_baby_carrots': 244,
#  'mild_chunky_salsa': 245,
#  'spinach_pizza': 246,
#  'spanish_rice_pilaf_mix': 247,
#  'grilled_chicken_breast': 248,
#  'ancient_grain_original_granola': 249,
#  'bing_cherries': 250,
#  'oregano': 251,
#  'dried_sweetened_cranberries': 252,
#  'original_coconut_milk_creamer': 253,
#  'total_plain_greek_strained_yogurt': 254,
#  'petite_brussels_sprouts': 255,
#  'organic_85%_cacao_dark_chocolate_bar': 256,
#  'select_a_size_paper_towels__white__2_huge_rolls_=_5_regular_rolls__towels/napkins': 257,
#  'traditional_refried_beans': 258,
#  'cherry_pomegranate_greek_yogurt': 259,
#  'american_cheese_slices_12_count': 260,
#  'philadelphia_cream_cheese': 261,
#  'organic_beef_uncured_hot_dogs': 262,
#  'tortillas__corn__organic': 263,
#  'all_natural_virgin_lemonade': 264,
#  'heavy_cream': 265,
#  'chunky_medium_salsa': 266,
#  'corn_maize_tortillas': 267,
#  'pink_lady_apples': 268,
#  'organic_california_style_sprouted_bread': 269,
#  'baby_carrots': 270,
#  'original_whole_fat_lactose_free_milk': 271,
#  'wheat_thins_reduced_fat_crackers': 272,
#  'gluten_free_chicken_nuggets': 273,
#  'dairy_free_coconut_milk_raspberry_yogurt_alternative': 274,
#  'solid_white_albacore_tuna_in_water': 275,
#  'blueberry_muffin_bar': 276,
#  'unsweetened_almond_milk': 277,
#  'shredded_mexican_blend_cheese': 278,
#  'fresh_mozzarella_snacking_cheese': 279,
#  'chopped_organic_garlic': 280,
#  'peanut_butter_bar': 281,
#  'low_fat_plain_yogurt': 282,
#  'hearty_grains_100%_whole_wheat_english_muffins': 283,
#  'broccoli_rabe': 284,
#  'gluten_free_pretzel_sticks': 285,
#  'panda_puffs_peanut_butter_cereal': 286,
#  'organic_large_grade_a_eggs': 287,
#  'organic_fancy_shredded_mozzarella_cheese': 288,
#  'healthy_grains_oats_&_honey_clusters_with_toasted_coconut_gluten_free': 289,
#  'chicken_flavor_ramen_noodle_soup': 290,
#  'green_leaf_shreds': 291,
#  'organic_mini_homestyle_waffles': 292,
#  'ultra_plush_3_ply_toilet_paper_12_double_rolls': 293,
#  'cookie_dough_ice_cream_chocolate_chip': 294,
#  'ground_turkey': 295,
#  'country_white_bread': 296,
#  'organic_uncured_beef_hot_dog': 297,
#  'mocha_almond_fudge_minis_almond_milk_frozen_dessert': 298,
#  'peach___apricot_&_banana_stage_2_baby_food': 299,
#  'organic_raspberry_lowfat_yogurt': 300,
#  'medium_cheddar_cheese': 301,
#  'pizza_poppers__three_cheese': 302,
#  'honey_&_maple_turkey_breast': 303,
#  'pure_granulated_cane_sugar': 304,
#  'raw_shrimp': 305,
#  'brown_fertile_large_grade_aa_eggs': 306,
#  'half_and_half_cream': 307,
#  'coconut_milk': 308,
#  'italian_dry_salame': 309,
#  'semi_sweet_chocolate_premium_baking_chips': 310,
#  'new_orleans_iced_coffee': 311,
#  'organic_sage': 312,
#  'watermelon_agave_frozen_pops': 313,
#  'organic_homestyle_mini_waffles': 314,
#  'diet_dr.pepper_soda_pack': 315,
#  'organic_yellow_zucchini': 316,
#  'gogo_squeez_organic_apple_strawberry_applesauce_on_the_go': 317,
#  'natural_artesian_bottled_water': 318,
#  'extralean_ground_turkey_breast': 319,
#  'organic_quinoa_&_brown_rice_with_garlic': 320,
#  'free_&_clear_natural_laundry_detergent_for_sensitive_skin': 321,
#  'organic_italian_herb_pasta_sauce': 322,
#  'original_baked_snack_crackers': 323,
#  'broccoli_bunch': 324,
#  'pizza_4_cheese': 325,
#  'fresh_whole_chicken': 326,
#  'cinnamon_swirl_raisin_bread': 327,
#  'organic_white_bread_done_right': 328,
#  'lemon_fruit_&_nut_food_bar': 329,
#  'mixed_vegetables': 330,
#  'pinto_beans_no_salt_added': 331,
#  '1_liter': 332,
#  'double_stuf_oreo_sandwich_cookies': 333,
#  'mini_seedless_watermelon_pack': 334,
#  'clean_care_mega_rolls_toilet_paper': 335,
#  'garbanzo_beans': 336,
#  'beyond_beef_beefy_crumble': 337,
#  'plain_goat_milk_yogurt': 338,
#  'turkey': 339,
#  'all_whites_100%_egg_whites': 340,
#  'wild_albacore_tuna_no_salt_added': 341,
#  'smartfood_white_cheddar_cheese_popcorn': 342,
#  'deli_fresh_smoked_turkey_breast': 343,
#  'organic_whole_milk_french_vanilla_yogurt': 344,
#  'leaf_spinach': 345,
#  'zen_tea': 346,
#  'sea_salt_fine_crystals': 347,
#  'shredded_carrots': 348,
#  'sweet_red_grape_tomatoes': 349,
#  'bag_of_lemons': 350,
#  'cran_raspberry_flavored_sparkling_water': 351,
#  'whole_wheat_tandoori_naan': 352,
#  'vanilla_soy_creamer': 353,
#  'chopped_pecans': 354,
#  'original_english_muffins': 355,
#  'diet_12_oz_ginger_ale': 356,
#  'stage_1_apples_sweet_potatoes_pumpkin_&_blueberries_organic_pureed_baby_food': 357,
#  'vitaminwater_zero™_xxx_acai_blueberry_pomegranate': 358,
#  'gluten_free_mushroom_risotto_bowl': 359,
#  'homemade_hot_arrabbiata_fra_diavolo_sauce': 360,
#  'herb_crackers': 361,
#  'vanilla_bean_ice_cream': 362,
#  'chicken_&_apple_breakfast_sausage': 363,
#  'mini_watermelon': 364,
#  'low_fat_strawberry_banana_on_the_bottom_greek_yogurt': 365,
#  'house_blend_deep_roast_ground_coffee': 366,
#  'hampshire_100%_natural_sour_cream': 367,
#  'natural_lemon_flavored_sparkling_water': 368,
#  'organic_mushroom_&_olive_pizza': 369,
#  'bag_of_large_lemons': 370,
#  'organic_vanilla_soymilk': 371,
#  'organic_skim_milk_with_dha_omega_3': 372,
#  'organic_roasted_red_pepper_&_tomato_soup': 373,
#  'organic_whole_peeled_baby_carrots': 374,
#  'vanilla_milk_chocolate_almond_ice_cream_bars': 375,
#  'spicy_hummus': 376,
#  'fully_husked_&_trimmed_super_sweet_corn': 377,
#  'organic_hot_salsa': 378,
#  'nutritional_yeast_seasoning': 379,
#  'brown_eggs': 380,
#  'diet_ginger_ale': 381,
#  'unsweetened_iced_coffee': 382,
#  'organic_sproutofu_savory_baked_tofu': 383,
#  'organic_australian_style_vanilla_lowfat_yogurt': 384,
#  'red_onions': 385,
#  'tortilla_strips_restaurant_style': 386,
#  'natural_liquid_laundry_detergent___blue_eucalyptus_and_lavender': 387,
#  'organic_celery': 388,
#  'gluten_free_red_hot_blues_made_with_organic_blue__corn_tortilla_chips': 389,
#  'yellow_corn_organic_tortillas': 390,
#  'farfalle_no._93': 391,
#  'dark_red_kidney_beans': 392,
#  'restaurant_style_organic_chia_&_quinoa_tortilla_chips': 393,
#  'unscented_1000_sheets_per_roll_bathroom_tissue': 394,
#  'baked_snack_crackers_original': 395,
#  'classic_wheat_bread': 396,
#  'natural_cane_turbinado_sugar': 397,
#  'eggo_chocolate_chip_waffles': 398,
#  'diet_root_beer': 399,
#  'organic_sproutofu_teriyaki_tofu_cutlets': 400,
#  'artisan_sausage_pineapple_uncured_bacon_hardwood_smoked_with_vermont_maple_syrup': 401,
#  'organic_chocolate_almondmilk_pudding': 402,
#  'organic_white_basmati_rice': 403,
#  'wild_sockeye_salmon': 404,
#  'light_&_lean_pasta_&_veggie_bowl': 405,
#  'premium_epsom_salt': 406,
#  'non_fat_blueberry_on_the_bottom_greek_yogurt': 407,
#  'country_cheddar_bowl': 408,
#  'dishwasher_gel_free_&_clear': 409,
#  'rosemary_mini_croccantini': 410,
#  'salsa__roja__hot': 411,
#  'organic_4%_milk_fat_whole_milk_cottage_cheese': 412,
#  'squeeze_pouch_sour_cream': 413,
#  'red_cabbage': 414,
#  'non_fat_vanilla_blended_greek_yogurt': 415,
#  'unsweetened_organic_coconut_milk': 416,
#  'organic_eggplant': 417,
#  'sweet_kale_chopped_salad': 418,
#  'organic_green_peas': 419,
#  'maple_pumpkin_seeds_with_sea_salt_chewy_with_a_crunch_granola_bars': 420,
#  'organic_campari_cocktail_tomatoes': 421,
#  'tomato_basil_marinara_sauce': 422,
#  'mini_peeled_carrots': 423,
#  'english_muffins': 424,
#  'whole_hearts_of_palm': 425,
#  'cheese_puffs_original': 426,
#  'paper_towels': 427,
#  'little_bites_chocolate_chip_muffins': 428,
#  'rice_krispies_cereal': 429,
#  'organic_cheddar_bunnies': 430,
#  'lavender_floral_&_mint_natural_dish_liquid': 431,
#  'vanilla_milk_chocolate_almond_ice_cream_bars_multi_pack': 432,
#  '3_lb_clementines': 433,
#  'classic_meatless_meatballs': 434,
#  'original_diced_tomatoes_&_green_chilies': 435,
#  'navel_orange': 436,
#  'mango_sparkling_water': 437,
#  'american_cheese_slices': 438,
#  'old_style_whole_grain_dijon_mustard': 439,
#  'heavy_duty_scrub_sponges': 440,
#  'dark_red_kidney_beans_no_salt_added': 441,
#  'pure_almond_unsweetened_original_almond_milk': 442,
#  'chicken_thighs': 443,
#  'original_strawberry_banana_yogurt': 444,
#  'rosemary_ham': 445,
#  'diet_pepsi_pack': 446,
#  'cheese_ravioli_with_sauce_bowls': 447,
#  'apple_apple_applesauce_on_the_go_pouches': 448,
#  'imported_mineral_water': 449,
#  'organic_reduced_fat_omega_3_milk': 450,
#  'black_beans_reduced_sodium': 451,
#  'organic_lemon_lowfat_yogurt': 452,
#  'cheese_enchilada_meal': 453,
#  'organic_sproutofu_super_firm_tofu': 454,
#  'hearty_thick_cut_bacon': 455,
#  '60%_cacao_bittersweet_premium_baking_chips': 456,
#  'honey_turkey_breast': 457,
#  'humboldt_fog': 458,
#  'low_sodium_beef_broth': 459,
#  'key_limes': 460,
#  'natural_lime_flavor_sparkling_mineral_water': 461,
#  'organic_chicken_pot_pie': 462,
#  'organic_whole_grain_oatmeal_cereal_baby_food': 463,
#  'natural_deli_style_sliced_swiss_cheese': 464,
#  'okra': 465,
#  'lavender_dish_soap': 466,
#  'green_peas_no_salt_added': 467,
#  'pecorino_romano': 468,
#  'organic_mint_bunch': 469,
#  'diet_soda': 470,
#  'brie': 471,
#  '100%_natural_diced_tomatoes': 472,
#  'uncured_hickory_smoked_bacon': 473,
#  'defense_up_cold_pressed_fruit_smoothie': 474,
#  '100%_recycled_aluminum_foil': 475,
#  'petit_suisse_fruit': 476,
#  'easy_open_tabsbags': 477,
#  'original_cooking_spray': 478,
#  'rice_krispies_treats_original_crispy_marshmallow_squares': 479,
#  'vegan_aged_white_cheddar_flavor_puffs': 480,
#  'toasted_coconut_chips_original_recipe': 481,
#  'country_morning_white_bread': 482,
#  'sparkling_pomegranate': 483,
#  'purple_cauliflower': 484,
#  '37%_less_sodium_soy_sauce': 485,
#  "annie's_bunny_fruit_snacks_variety": 486,
#  'olive_oil_cooking_spray': 487,
#  'ultra_soft_bathroom_tissue_double_rolls': 488,
#  'linguine_pasta': 489,
#  'original_whipped_topping': 490,
#  'roasted_salted_peanuts': 491,
#  'organic_lowfat_plain_yogurt': 492,
#  'dairy_free_coconut_milk_chocolate_yogurt_alternative': 493,
#  'teriyaki_chicken_bowl': 494,
#  'low_fat_cottage_cheese': 495,
#  'fridge_and_freezer_baking_soda_pack': 496,
#  'spicy_avocado_hummus': 497,
#  'calcium_enriched_100%_lactose_free_fat_free_milk': 498,
#  'chili_powder': 499,
#  'peach_pear_sparkling_water': 500,
#  'pinot_noir': 501,
#  'tomatillo_salsa': 502,
#  'lemon_cake_ice_cream': 503,
#  'napa_cabbage': 504,
#  'semi_sweet_mini_chocolate_chips': 505,
#  'organic_promise_strawberry_fields_cereal': 506,
#  'all_natural_french_toast_sticks': 507,
#  'parchment_paper': 508,
#  'sparkling_orange_juice_&_prickly_pear_beverage': 509,
#  'diet_coke_caffeine_free_soda': 510,
#  'deli_fresh_rotisserie_seasoned_chicken_breast': 511,
#  'organic_salted_individually_wrapped_quarters_butter': 512,
#  'organic_capellini': 513,
#  'honey_graham_sticks': 514,
#  'indian_paneer_tikka': 515,
#  'liquid_aminos_all_purpose_seasoning': 516,
#  'shaved_brussel_sprouts': 517,
#  'world_cuisine_certified_halal_chicken_tikka_masala_with_basmati_rice': 518,
#  'organic_medium_brown_eggs': 519,
#  'strained_whole_milk_yogurt_blueberry': 520,
#  'dried_mangos': 521,
#  'low_fat_kefir_cultured_milk_smoothie_lowfat_probiotic_blueberry': 522,
#  'royal_gala_apples': 523,
#  'organic_cottage_cheese_classic': 524,
#  'organic_homogenized_whole_milk': 525,
#  'yotoddler_organic_pear_spinach_mango_yogurt': 526,
#  'organic_turmeric': 527,
#  'the_\\"world\'s_best\\"_veggie_burger': 528,
#  'organic_vanilla_chip_chewy_granola': 529,
#  '100%_whole_wheat_pre_sliced_sandwich_thins': 530,
#  'meyer_lemons': 531,
#  'organic__sweet_&_salty_peanut_pretzel_granola_bars': 532,
#  'beef_loin_new_york_strip_steak': 533,
#  'organic_gluten_&_wheat_free_homestyle_waffles': 534,
#  'tater_puffs': 535,
#  'gluten_free_multi_seed_rice_thin_crackers': 536,
#  'cream_top_smooth_&_creamy_plain_yogurt': 537,
#  'organic_white_english_muffins': 538,
#  'ice_bag': 539,
#  'organic_love_crunch_granola_dark_chocolate_&_red_berries': 540,
#  'organic_strawberry_lemonade': 541,
#  'three_cheese_mini_pizza_bagels_frozen_snacks': 542,
#  'boneless_beef_chuck_roast': 543,
#  'soft_potato_bread': 544,
#  'honey_vanilla_greek_yogurt': 545,
#  'honey_dijon_potato_chips': 546,
#  'bite_size_tortilla_chips': 547,
#  'original_glass_cleaner': 548,
#  'traditional_98%_fat_free': 549,
#  'breakfast_blend_medium_keurig_brewed_k_cups_ground_coffee': 550,
#  'vegetable_medley': 551,
#  'organic_whole_wheat_elbows': 552,
#  'red_bell_peppers': 553,
#  'tangerine_juice': 554,
#  'black_peppercorns': 555,
#  'free_and_gentle_high_efficiency_liquid_laundry_detergent': 556,
#  'frosted_flakes': 557,
#  'organic_tarragon': 558,
#  '100%_oatnut_bread': 559,
#  'strained_non_fat_orange_&_ginger_yogurt': 560,
#  'original_bbq_sauce': 561,
#  'vegetarian_organic_golden_corn': 562,
#  'whole_wheat_cookies_dark_chocolate': 563,
#  'ezekiel_4:9_flax_sprouted_grain_bread': 564,
#  'organic_whole_wheat_sourdough_bread': 565,
#  'large_enriched_bread': 566,
#  'pita_crisps_simply_naked': 567,
#  'simply_naked_pita_chips': 568,
#  'organic_garlic_powder': 569,
#  'lemon_italian_sparkling_mineral_water': 570,
#  'mango_tango_fruit_smoothie_blend': 571,
#  'organic_fat_free_cottage_cheese': 572,
#  'large_brown_free_range_eggs_grade_a': 573,
#  'extra_sharp_cheddar_cheese': 574,
#  'roasted_sesame_seaweed_snacks': 575,
#  'organic_ground_flaxseed': 576,
#  'ginger_beer': 577,
#  'rising_crust_supreme_(sausage__pepperoni__red_peppers__green_peppers__onions__black_olives)_frozen_pizza': 578,
#  'brownberry_natural_wheat_bread': 579,
#  "s'mores_luna_bar": 580,
#  'dairy_free_hazelnut_coconut_milk_creamer': 581,
#  'beyond_beef_fiesty_crumble': 582,
#  'shaved_parmesan': 583,
#  'quick_1_minute_oatmeal': 584,
#  'pinot_grigio': 585,
#  'verde_salsa': 586,
#  'organic_rice_vinegar': 587,
#  'dijon_mustard_squeeze_bottle': 588,
#  'roasted_red_pepper_hommus': 589,
#  'classic_whipped_cream': 590,
#  'peanut_butter_chocolate_chip_macrobar': 591,
#  'poppy_seed_dressing': 592,
#  'single_serve_cheese_pizza': 593,
#  'pears__kale_&_spinach_organic_baby_food': 594,
#  'tamari_gluten_free_soy_sauce_reduced_sodium': 595,
#  'unsweetened_whole_milk_peach_greek_yogurt': 596,
#  'organic_pineapple_chunks': 597,
#  'plain_better_than_cream_cheese': 598,
#  'vitamin_c_super_orange_dietary_supplement': 599,
#  'ravioli__spinach_&_cheese': 600,
#  'sweet_potato_(yam)': 601,
#  'plus_cranberry_almond_+_antioxidants_with_macadamia_nuts_bar': 602,
#  'star_wars_italian_sweet_creme_creamer': 603,
#  'snacks_mango': 604,
#  'hickory_smoked_turkey_breast': 605,
#  'kitchen_scrubber_sponge': 606,
#  'orignial_recipe_chocolate_pudding': 607,
#  'truffle_popcorn': 608,
#  'coconut_water__pure_organic': 609,
#  'artichoke_hearts': 610,
#  'natural_anticavity_silly_strawberry_fluoride_toothpaste_for_children': 611,
#  'organic_sweet_relish': 612,
#  'fruit_punch_juice_drink': 613,
#  'vodka_pasta_sauce': 614,
#  'light_&_lean_spaghetti_italiano_with_meatless_meatballs': 615,
#  'tomato_and_basil_bombolina_pasta_sauce': 616,
#  'vegetarian_grain_meat_sausages_italian___4_ct': 617,
#  'mayonnaise': 618,
#  'grade_aa_extra_large_eggs': 619,
#  'nectarines': 620,
#  'fresh_ciliegine_mozzarella_cheese': 621,
#  'gluten_free_pizza_crust': 622,
#  'all_natural_no_stir_creamy_almond_butter': 623,
#  'vitaminwater®_xxx_acai_blueberry_pomegranate': 624,
#  "shepherd's_pie": 625,
#  'gluten_free_supergrain_pasta_organic_corn_&_quinoa_blend_penne': 626,
#  'traditional_scottish_style_smoked_salmon': 627,
#  'berry_valley_blueberries': 628,
#  'organic_fire_roasted_corn': 629,
#  'black_tea_pyramids': 630,
#  'unsweetened_vanilla_cashew_milk': 631,
#  'first_prunes': 632,
#  'asparagus_spears': 633,
#  'organic_flax_plus_multibran_flakes': 634,
#  'extra_lean_ground_turkey_breast': 635,
#  'tulips_10_stem': 636,
#  'roasted_salted_almonds': 637,
#  '15_grain_whole_grain_bread': 638,
#  'feta_cheese': 639,
#  'organic_bagged_mini_milk_peanut_butter': 640,
#  'crunchy_organic_dark_roasted_peanut_butter': 641,
#  'organic_italian_dressing': 642,
#  'mache_blend': 643,
#  'limonata_sparkling_lemon_beverage': 644,
#  'honey_ham': 645,
#  'bag_of_oranges': 646,
#  'ground_cinnamon': 647,
#  'corn_starch': 648,
#  'sweeper_open_window_fresh_scent_wet_mopping_cloths_refill': 649,
#  'almond_milk_vanilla_frozen_dessert_sandwich': 650,
#  'freeze_dried_strawberry_slices': 651,
#  'ancient_grain_blueberry_hemp_granola': 652,
#  'chocolate_peppermint_stick_bar': 653,
#  'lettuce_red_butter_organic': 654,
#  'boniato_sweet_potato': 655,
#  'organic_sensible_sipper_apple_juice': 656,
#  'dry_roasted_almonds': 657,
#  'fully_cooked_original_bacon': 658,
#  'mighty_4_sweet_potato__blueberry__millet_&_greek_yogurt_tots_snack': 659,
#  'organic_sproutofu_silken_tofu': 660,
#  'vegan_cheddar_style_cheese_slices': 661,
#  'sesame_seed': 662,
#  'greek_whole_milk_blended_blueberry_yogurt': 663,
#  'whipped_butter': 664,
#  'milk_whole': 665,
#  'jumbo_grade_a_eggs': 666,
#  'total_2%_with_raspberry_pomegranate_lowfat_greek_strained_yogurt': 667,
#  'milk__fat_free': 668,
#  'organic_honey_mustard': 669,
#  'turkey_franks': 670,
#  'french_vanilla_ice_cream': 671,
#  'single_serve_crispy_wheat_crackers': 672,
#  'mediterranean_thin_crust_pizza': 673,
#  'chocolate_chip_cookie_dough_bar': 674,
#  'cheese_ravioli': 675,
#  'organic_diced_fire_roasted_tomatoes': 676,
#  'organic_baby_romaine': 677,
#  'selects_turkey_hot_dogs': 678,
#  'unsweetened_blackberry_water': 679,
#  'baked_whole_grain_wheat_cracked_pepper_&_olive_oil_crackers': 680,
#  'organic_avocados': 681,
#  'stage_1_apples_&_strawberries_organic_pureed_baby_food': 682,
#  'chicken_breast_tenders': 683,
#  'yellow_corn_taco_shells': 684,
#  'olive_oil_&_vinegar_dressing': 685,
#  'dairy_free_coconut_milk_passionate_mango_yogurt_alternative': 686,
#  'organic_hazelnut_spread': 687,
#  'uncured_hard_salami': 688,
#  'mango_sorbet': 689,
#  'mild_cheddar_cheese': 690,
#  'apricots': 691,
#  'dark_chocolate_almond_milk': 692,
#  'muffins__mini__flax__chocolate_brownie': 693,
#  'complete™_actionpacs™_fresh_scent_dishwasher_detergent': 694,
#  'trilogy_kombucha': 695,
#  'organic_southwest_taco_seasoning': 696,
#  'extra_dark_chocolate_baking_chips': 697,
#  'dark_blackout_organic_chocolate': 698,
#  'italian_sparkling_pomegranate_and_orange_soda': 699,
#  'unsweetened_whole_milk_mixed_berry_greek_yogurt': 700,
#  'original_unsweetened_dairy_free_beverage': 701,
#  'april_fresh_liquid_fabric_softener': 702,
#  'regular': 703,
#  'eggo_nutri_grain_blueberry_waffles': 704,
#  'lemon_blended_non_fat_greek_yogurt': 705,
#  'mint_chocolate_cookie_ice_cream': 706,
#  'light_&_lean_black_bean_and_cheese_enchilada': 707,
#  'organic_red_cherry_tomato': 708,
#  'half_and_half': 709,
#  'organic_gluten_free_quinoa_spaghetti': 710,
#  'cheddar_cheese_medium': 711,
#  'organic_chicken_&_wild_rice_soup': 712,
#  'bagel_bites_three_cheese_mini_bagel_pizzas': 713,
#  'plain_soymilk_creamer': 714,
#  'vanilla_sandwich_creme_cookies': 715,
#  'vanilla_coconut_milk_yogurt': 716,
#  'organic_red_heirloom_pasta_sauce': 717,
#  'gluten_free_paleo_fettuccine': 718,
#  "nutty_for_'nana_low_fat_greek_yogurt": 719,
#  'organic_animal_crackers': 720,
#  'beef_broth': 721,
#  'dark_chocolate_coconut_almond_bark': 722,
#  'multi_grain_sea_salt_crackers': 723,
#  'grated_parmigiano_reggiano': 724,
#  'organic_cashew_carrot_ginger_soup': 725,
#  'coffee_mate_natural_bliss_sweet_creme_coffee_creamer': 726,
#  'frosted_flakes_cereal': 727,
#  'white_beauty_bar': 728,
#  'low_sodium_refried_black_beans': 729,
#  'organic_plain_unsweetened_nondairy_cashew_yogurt': 730,
#  'salted_caramel_lean_protein_&_fiber_bar': 731,
#  'dolmas': 732,
#  'mini_babybel_mozzarella_cheese': 733,
#  'organic_hass_avocado_bag': 734,
#  'friends_honey__chocolate_&_chocolate_chip_bunny_grahams_whole_grain_snacks': 735,
#  'kosher_dill_pickle_spears': 736,
#  'cheese_&_pepperoni_mini_bagels': 737,
#  'ice_pops_sugar_free__orange__cherry__grape': 738,
#  'simple_favorites_chicken_enchilada_suiza': 739,
#  'feta_crumbled_traditional_cheese': 740,
#  'caesar_supreme_salad_kit': 741,
#  'revive_zero_vitamin_water': 742,
#  'makeup_remover_cleansing_towelettes': 743,
#  'cauliflower_crumbles': 744,
#  'avocado_oil_himalayan_salt_chips': 745,
#  'organic_caesar_dressing': 746,
#  'lowfat_raspberry_kefir_probiotic_cultured_milk_smoothie': 747,
#  'hummus': 748,
#  'original_baked_beans': 749,
#  'potato_gnocchi': 750,
#  'raspberry_cereal': 751,
#  'macaroni_elbows': 752,
#  'pasta_joy_ready_organic_brown_rice_pasta_penne': 753,
#  'tofu_miso_ramen': 754,
#  'shelled_pistachios': 755,
#  'premium_sliced_bacon': 756,
#  'bowls_tortilla_casserole_&_black_beans': 757,
#  'lafayette_butter_lettuce_&_radicchio_salad_blend': 758,
#  'natural_creamy_peanut_butter': 759,
#  'kombucha_gingerade': 760,
#  'cool_mint_chocolate': 761,
#  'carb_balance_small_fajita_whole_wheat_tortillas': 762,
#  'coconut_yogurt': 763,
#  '100%_lactose_free_1%_lowfat_milk': 764,
#  'cool_ranch_tortilla_chips': 765,
#  'fettuccine_pasta': 766,
#  'pop_tarts_frosted_strawberry_toaster_pastries': 767,
#  "veggie_lover's_salad_blend": 768,
#  'vegetable_pot_pie': 769,
#  'cheddar_puffs': 770,
#  'ginger_root': 771,
#  "organic_bernie_o's": 772,
#  'spinach_and_ricotta_ravioli': 773,
#  'organic_balsamic_vinaigrette': 774,
#  '12_grain_bread': 775,
#  'smoked_gouda': 776,
#  'brown_extra_large_grade_aa_eggs': 777,
#  'flip_peanut_butter_dream_greek_yogurt': 778,
#  'less_sodium_soy_sauce': 779,
#  'organic_carrots': 780,
#  'whole_grain_loaf': 781,
#  'honest_face__hand__&_baby_wipes': 782,
#  'traditional_favorites_four_cheese_pasta_sauce': 783,
#  'non_scratch_scrub_sponges': 784,
#  'to_go_creamy_peanut_butter_cups': 785,
#  'squash_&_sweet_peas_stage_2': 786,
#  "naturе's_calorie_free_sweetener": 787,
#  'special_k_original_cereal': 788,
#  'cinnamon_applesauce': 789,
#  'lunchables_turkey_&_american_cheese_cracker_stackers': 790,
#  'geranium_liquid_dish_soap': 791,
#  'family_size_shells_&_white_cheddar_macaroni_&_cheese': 792,
#  'pistachios': 793,
#  'aged_white_wine_vinegar': 794,
#  'white_cheddar_baked_snack_crackers': 795,
#  'organic_soft_white_bread': 796,
#  '15_calories_light_lemonade': 797,
#  'small_compostable_waste_bag': 798,
#  'strawberry_banana_juice': 799,
#  'organic_alfalfa_sprouts': 800,
#  'organic_apple_&_butternut_squash_baby_food': 801,
#  'cayenne_pepper': 802,
#  'cinnamon_&_spice_instant_oatmeal': 803,
#  'vanilla_protein_protein_shake': 804,
#  'cup_noodles_chicken_flavor': 805,
#  'mayo_made_with_avocado_oil': 806,
#  'krinkle_cut_classic_barbecue_potato_chips': 807,
#  'orange_mango_sparkling_water': 808,
#  'string_cheese': 809,
#  'organic_crushed_red_pepper': 810,
#  'fresh_goat_cheese': 811,
#  'italian_salad_blend': 812,
#  'deluxe_everything_bagels': 813,
#  'pineapple_yogurt_2%': 814,
#  'organic_baby_lettuces': 815,
#  'vidalia_onions': 816,
#  'instant_coffee': 817,
#  'mango_sorbet_pops': 818,
#  'organic_cashew_nondairy_blueberry_yogurt': 819,
#  'milk_chocolate_covered_raisins': 820,
#  'chocolate_peanut_butter_protein_bar': 821,
#  'baked_whole_grain_reduced_fat_crackers': 822,
#  'grain_free_chicken_formula_cat_food': 823,
#  'fabric_softener_dryer_sheet_outdoor_fresh_160ct_fabric_enhancers': 824,
#  'organic_baby_food_banana_beet_&_blueberry': 825,
#  'microwaveable_100%_beef_cheeseburgers': 826,
#  'original_buttery_spread': 827,
#  'pico_de_gallo': 828,
#  'organic_bran_flakes_cereal': 829,
#  'eggs__cheese_&_turkey_sausage_breakfast_burrito': 830,
#  'chips_ahoy!_chewy_cookies': 831,
#  '24/7_performance_cat_litter': 832,
#  'culinary_coconut_milk': 833,
#  'diced_butternut_squash': 834,
#  'peppermint': 835,
#  'fresh_pressed_virgin_coconut_oil': 836,
#  'oh_my_yog!_madagascar_vanilla_trilayer_yogyurt': 837,
#  'vegan_hickory_&_sage_benevolent_bacon': 838,
#  'hearts_of_palm': 839,
#  'traditional_basil_pesto_sauce': 840,
#  'organic_brown_rice_crisps_cereal': 841,
#  'mushroom_and_ricotta_ravioli': 842,
#  'organic_california_sushi_rice': 843,
#  'snack_bags': 844,
#  'asian_vegetable_ramen': 845,
#  'organic_turkey_burgers': 846,
#  'original_mashed_potatoes': 847,
#  'strawberry_explosion/banana_split_smoothie': 848,
#  'honeysuckle_hand_soap': 849,
#  'organic_berry_basket_blend': 850,
#  'organic_diced_tomatoes_with_italian_herbs': 851,
#  'classic_roast_medium_ground_coffee': 852,
#  'sweet_garden_peas': 853,
#  'blueberry_crisp_energy_bar': 854,
#  'original_craisins': 855,
#  'ancient_grain_granola_cranberry_pecan': 856,
#  'deli_sliced_sharp_cheddar_cheese': 857,
#  'all_natural_classic_guacamole_snack': 858,
#  'wheat_thins_original': 859,
#  'dolmas_stuffed_grape_leaves': 860,
#  'salted_caramel_yoghurt': 861,
#  'turkey_pepperoni_slices': 862,
#  'organic_roasted_seaweed_snacks_teriyaki': 863,
#  'dry_roasted_peanuts': 864,
#  'carrot_and_broccoli_baby_food_puree': 865,
#  'energy_tropical_citrus_vitamin_water_drink': 866,
#  'original_corn_chips': 867,
#  'mighty_4_kale__strawberry__amaranth_&_greek_yogurt_tots_snack': 868,
#  'organic_corn_thins__original': 869,
#  'wild_chanterelle_mushroom_ravioli': 870,
#  'pure_coconut_milk': 871,
#  'vegan_oatmeal_chocolate_chip_cookies': 872,
#  'hazelnut_spread_with_cocoa': 873,
#  'organic_letter_of_the_day_oatmeal_cinnamon_cookies': 874,
#  'raspberries_dark_chocolate_bar': 875,
#  'veggie_style_mini_corn_dogs': 876,
#  'roasted_mushroom_pizza': 877,
#  'shaved_parmesan_cheese': 878,
#  'natural_uncured_beef_hot_dog': 879,
#  'apples_&_cinnamon_instant_oatmeal': 880,
#  'organic_creamy_tomato_basil_soup': 881,
#  'light_butter_with_canola': 882,
#  'pancake_&_baking_mix': 883,
#  'pure_dark_brown_cane_sugar': 884,
#  'cool_mint®_antiseptic_adult_mouthwash': 885,
#  'essential_greens_with_lime_vegetable_and_fruit_juice_blend': 886,
#  'direct_trade_organic_el_gallo_breakfast_blend_whole_bean_coffee': 887,
#  'original_string_cheese': 888,
#  'tomato_basil_cooking_sauce': 889,
#  'laundry_detergent_free_&_clear': 890,
#  'organic_cream_of_chicken_condensed_soup': 891,
#  'organic_fruitful_os_cereal': 892,
#  'seasoning__italian': 893,
#  'crunchy_rice_rollers': 894,
#  'chipotle_lime_meat_free_crispy_fingers': 895,
#  'teriyaki_meal_bowls': 896,
#  'plusshot_blueberry_acai_probiotic_juice_drink': 897,
#  'garlic_pepper_ramen': 898,
#  'extra_soft_double_roll_bathroom_tissue': 899,
#  'mixed_berries': 900,
#  'spicy_salmon_avocado_roll': 901,
#  'linguine_no_7_pasta': 902,
#  'original_100%_pure_no_pulp_orange_juice': 903,
#  'strawberry_and_banana_fruit_puree': 904,
#  '99%_fat_free_chicken_broth': 905,
#  'uncrustables_peanut_butter_&_strawberry_spread_sandwich': 906,
#  'gluten_free_extra_crispy_fast_food_french_fried_potatoes': 907,
#  'dark_chocolate_pumpkin_seed_bark': 908,
#  'organic_mocha_coffee_concentrate': 909,
#  'blackberry_preserves': 910,
#  'pop_tarts_frosted_brown_sugar_cinnamon_toaster_pastries': 911,
#  'homestyle_savory_chicken_bone_broth': 912,
#  'unprocessed_american_singles_colby_style_cheese': 913,
#  'icelandic_style_cream_skyr_4%_milkfat_strained_whole_milk_yogurt_mango': 914,
#  'mellow_white_miso': 915,
#  'diced_red_onions': 916,
#  'stuffed_grape_leaves': 917,
#  'garden_vegetable_salad_roll': 918,
#  'organic_wild_blueberries': 919,
#  'organic_unsweetened_original_non_dairy_almond_beverage': 920,
#  'grands!_flaky_layers_buttermilk_biscuits': 921,
#  'baby_dill': 922,
#  'crackers__baked__crispy_sea_salt': 923,
#  "crunchy_oats_'n_honey_granola": 924,
#  'classic_crust_four_cheese_frozen_pizza': 925,
#  'sparkling_mineral_water__natural_lemon_flavor': 926,
#  'smoked_atlantic_nova_salmon': 927,
#  'organic_vegetarian_mild_refried_beans_with_green_chiles': 928,
#  "jack's_special_salsa_medium_hot": 929,
#  "lightly_seasoned_chick'n_scallopini": 930,
#  'free_range_chicken_broth': 931,
#  'organic_blue_agave': 932,
#  'organic_raw_pomegranate_kombucha': 933,
#  'bologna': 934,
#  "cracklin'_oat_bran_cereal": 935,
#  'milk_chocolate_minatures': 936,
#  'traditional_pasta_sauce': 937,
#  'pepperoni_pizza_frozen_sandwiches': 938,
#  'organic_chicken_&_mozzarella_ravioli': 939,
#  'crackers_almond_flour_rosemary_sea_salt': 940,
#  'organic_diced_tomatoes_fire_roasted_with_medium_green_chilies': 941,
#  'classic_baby_creamers_potatoes': 942,
#  'organic_baby_corn_pieces': 943,
#  'classic_coke': 944,
#  'strawberry': 945,
#  'black_and_white_cold_brew_coffee_with_almondmilk': 946,
#  'waffles__sweet_belgian__vanilla': 947,
#  'moroccan_mint_herbal_tea': 948,
#  'reduced_fat_sliced_swiss_cheese': 949,
#  'premium_romaine': 950,
#  "berries_'n_cherries_fruit_snacks": 951,
#  '2_ply_everyday_napkins': 952,
#  'organic_yellow_onions': 953,
#  'chocolate_sandwich_cookies': 954,
#  'green_house_grown_miraculously_sweet_tomatoes': 955,
#  'chunky_peanut_butter': 956,
#  'banana_bread_fruit_&_nut_bar': 957,
#  'pomegranate_blueberry_pistachio_plus_antioxidants_fruit_&_nut_bar': 958,
#  'gluten_free_supergrain_pasta_elbows': 959,
#  'lime_grain_free_tortilla_chips': 960,
#  'chicken_bouillon_cubes': 961,
#  'original_tortilla_strips': 962,
#  'hash_browns_country_style': 963,
#  'dipps_chocolatey_covered_chocolate_chip_granola_bars': 964,
#  '97%_fat_free_beef_franks': 965,
#  'raisin_bran': 966,
#  'gluten_free_chicken_dumplings': 967,
#  'organic_iced_green_tea': 968,
#  'organic_whole_milk_plain_kefir': 969,
#  '100%_florida_orange_juice': 970,
#  '2%_lactose_free_milk': 971,
#  'organic_pear_juice': 972,
#  'fully_cooked_turkey_sausage_links': 973,
#  'ciabatta': 974,
#  'naturally_brewed_soy_sauce': 975,
#  'zero_rise_orange': 976,
#  'kidz_baked_chicken_nuggets': 977,
#  'classic_mixed_vegetables': 978,
#  'simply_100_strawberry_blended_non_fat_greek_yogurt': 979,
#  'classic_lemonade': 980,
#  'organic_southwestern_burrito': 981,
#  'organic_tomato_bisque': 982,
#  'thin_rice_noodles': 983,
#  'sliced_genoa_salami': 984,
#  'pure_goat_milk_cheese_log': 985,
#  'navel_oranges_bag': 986,
#  'ultra_built_strong_paper_bowls': 987,
#  'french_onion_dip_mix': 988,
#  'chewy_peanut_butter_chocolate_chip_granola_bars': 989,
#  'organic_fudge_bars': 990,
#  'protein_zone_protein_juice_smoothie': 991,
#  'chicken_apple_sausage_egg_white_breakfast_burrito': 992,
#  'diet_orange_diet_csd': 993,
#  'organic_cheddar_squares': 994,
#  'frozen_desserts__cookies_and_cream': 995,
#  'sliced_tamed_jalapeno_peppers': 996,
#  'organic_waffles_flax_plus': 997,
#  'free_&_clear_all_purpose_natural_cleaner': 998,
#  'happy_tot_banana__peach__prune_&_coconut_organic_superfoods': 999,
#  'pepperoni': 1000,
#  ...}

# %%
max_len = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_len, padding='pre')
print('Max Sequence Length: %d' % max_len)
sequences = np.array(sequences)
# Out:
# Max Sequence Length: 5

# %%
X, y = sequences[:, :-1], sequences[:, -1]

# %%
print(X.shape, y.shape)
# Out:
# (74268, 4) (74268,)

# %%
y = to_categorical(y, num_classes=vocabulary_size)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from keras import Sequential
from keras.layers import Embedding, Dropout, LSTM, Dense
from keras.callbacks import EarlyStopping
model = Sequential()
model.add(Embedding(vocabulary_size, 4, input_length=max_len - 1))
model.add(LSTM(16))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(Dense(vocabulary_size, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 4, 4)              38072
#
#  lstm (LSTM)                 (None, 16)                1344
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense (Dense)               (None, 64)                1088
#
#  dense_1 (Dense)             (None, 9518)              618670
#
# =================================================================
# Total params: 659,174
# Trainable params: 659,174
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping 
es_callback = EarlyStopping(monitor='val_acc', patience=5, restore_best_weights=True)
h = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5000, callbacks=[es_callback])
import matplotlib.pyplot as plt

plt.plot(h.history['loss'], label='Train loss')
plt.plot(h.history['val_loss'], label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()
plt.plot(h.history['acc'], label='Train accuracy')
plt.plot(h.history['val_acc'], label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Epoch 1/5000
# 1857/1857 [==============================] - 31s 16ms/step - loss: 2.8374 - acc: 0.4074 - val_loss: 2.5849 - val_acc: 0.4064
# Epoch 2/5000
# 1857/1857 [==============================] - 28s 15ms/step - loss: 2.5139 - acc: 0.4484 - val_loss: 2.4891 - val_acc: 0.4663
# Epoch 3/5000
# 1857/1857 [==============================] - 29s 16ms/step - loss: 2.4558 - acc: 0.4717 - val_loss: 2.4589 - val_acc: 0.4663
# Epoch 4/5000
# 1857/1857 [==============================] - 29s 16ms/step - loss: 2.4339 - acc: 0.4716 - val_loss: 2.4448 - val_acc: 0.4663
# Epoch 5/5000
# 1857/1857 [==============================] - 27s 15ms/step - loss: 2.4232 - acc: 0.4721 - val_loss: 2.4421 - val_acc: 0.4669
# Epoch 6/5000
# 1857/1857 [==============================] - 25s 14ms/step - loss: 2.4178 - acc: 0.4729 - val_loss: 2.4395 - val_acc: 0.4676
# Epoch 7/5000
# 1857/1857 [==============================] - 25s 14ms/step - loss: 2.4149 - acc: 0.4731 - val_loss: 2.4370 - val_acc: 0.4679
# Epoch 8/5000
# 1857/1857 [==============================] - 26s 14ms/step - loss: 2.4129 - acc: 0.4726 - val_loss: 2.4337 - val_acc: 0.4682
# Epoch 9/5000
# 1857/1857 [==============================] - 27s 14ms/step - loss: 2.4103 - acc: 0.4731 - val_loss: 2.4360 - val_acc: 0.4684
# Epoch 10/5000
# 1857/1857 [==============================] - 28s 15ms/step - loss: 2.4088 - acc: 0.4736 - val_loss: 2.4315 - val_acc: 0.4676
# Epoch 11/5000
# 1857/1857 [==============================] - 26s 14ms/step - loss: 2.4057 - acc: 0.4735 - val_loss: 2.4308 - val_acc: 0.4680
# Epoch 12/5000
# 1857/1857 [==============================] - 27s 14ms/step - loss: 2.4036 - acc: 0.4738 - val_loss: 2.4277 - val_acc: 0.4683
# Epoch 13/5000
# 1857/1857 [==============================] - 27s 14ms/step - loss: 2.4020 - acc: 0.4745 - val_loss: 2.4286 - val_acc: 0.4668
# Epoch 14/5000
# 1857/1857 [==============================] - 26s 14ms/step - loss: 2.4010 - acc: 0.4734 - val_loss: 2.4246 - val_acc: 0.4682

# %%
model.save("")

# %%
tokenizer.word_index.items()
# Out:
# dict_items([('seedless_red_grapes', 1), ('organic_red_onion', 2), ('yellow_onions', 3), ('organic_lemon', 4), ('small_hass_avocado', 5), ('broccoli_crown', 6), ('organic_red_bell_pepper', 7), ('100%_whole_wheat_bread', 8), ('blueberries', 9), ('apple_honeycrisp_organic', 10), ('hass_avocados', 11), ('organic_navel_orange', 12), ('large_alfresco_eggs', 13), ('organic_broccoli', 14), ('organic_reduced_fat_2%_milk', 15), ('red_raspberries', 16), ('green_onions', 17), ('russet_potato', 18), ('organic_sticks_low_moisture_part_skim_mozzarella_string_cheese', 19), ('shredded_parmesan', 20), ('granny_smith_apples', 21), ('whole_milk', 22), ('cantaloupe', 23), ('vanilla_almond_breeze_almond_milk', 24), ('100%_raw_coconut_water', 25), ('yellow_bell_pepper', 26), ('baby_spinach', 27), ('100%_recycled_paper_towels', 28), ('organic_celery_hearts', 29), ('italian_sparkling_mineral_water', 30), ('clementines', 31), ('boneless_skinless_chicken_breast', 32), ('soda', 33), ('organic_2%_reduced_fat_milk', 34), ('white_onion', 35), ('organic_milk', 36), ('organic_diced_tomatoes', 37), ('watermelon_chunks', 38), ('organic_broccoli_crowns', 39), ('natural_spring_water', 40), ('sustainably_soft_bath_tissue', 41), ('english_seedless_cucumber', 42), ('mango_chunks', 43), ('unsalted_pure_irish_butter', 44), ('organic_unsalted_butter', 45), ('organic_tomato_paste', 46), ('basil_pesto', 47), ('pure_coconut_water', 48), ('organic_american_cheese_singles', 49), ('dressing__jersey_sweet_onion__calorie_free', 50), ('original_nooks_&_crannies_english_muffins', 51), ('grade_a_large_white_eggs', 52), ('diced_tomatoes', 53), ('total_2%_lowfat_greek_strained_yogurt_with_blueberry', 54), ('european_cucumber', 55), ('tomato_ketchup', 56), ('organic_turkey_bacon', 57), ('raisin_bran_cereal', 58), ('organic_whole_kernel_sweet_corn_no_salt_added', 59), ('toasted_coconut_almondmilk_blend', 60), ('fridge_pack_cola', 61), ('organic_iceberg_lettuce', 62), ('cauliflower', 63), ('italian_extra_virgin_olive_oil', 64), ('organic_whipped_naturally_buttery_spread', 65), ('mini_original_babybel_cheese', 66), ('2%_reduced_fat_dha_omega_3_reduced_fat_milk', 67), ('baked_aged_white_cheddar_rice_and_corn_puffs', 68), ('packaged_grape_tomatoes', 69), ('organic_salted_butter', 70), ('green_tea_with_ginseng_and_honey', 71), ('whole_milk_plain_yogurt', 72), ('baby_cucumbers', 73), ('tilapia_filet', 74), ('organic_english_cucumber', 75), ('organic_thompson_seedless_raisins', 76), ('organic_chicken_&_apple_sausage', 77), ('organic_orange_bell_pepper', 78), ('crushed_tomatoes', 79), ('mint', 80), ('plain_greek_yogurt', 81), ('organic_bunny_fruit_snacks_berry_patch', 82), ('gluten_free_whole_grain_bread', 83), ('lime', 84), ('organic_chicken_stock', 85), ('medium_cheddar_cheese_block', 86), ('cinnamon_rolls_with_icing', 87), ('naturals_chicken_nuggets', 88), ('organic_whole_grassmilk_milk', 89), ('sparkling_water', 90), ('cage_free_large_white_eggs', 91), ('organic_chicken_broth', 92), ('raspberry_preserves', 93), ('whole_almonds', 94), ('organic_vegetable_broth', 95), ('organic_butterhead_(boston__butter__bibb)_lettuce', 96), ('organic_original_hommus', 97), ('no_pulp_calcium_&_vitamin_d_pure_orange_juice', 98), ('taco_seasoning', 99), ('organic_multigrain_waffles', 100), ('garlic_&_fine_herbs_gournay_cheese', 101), ('dried_mango', 102), ('reduced_fat_milk', 103), ('organic_good_seed_bread', 104), ('scoops!_tortilla_chips', 105), ('boneless_skinless_chicken_thighs', 106), ('chocolate_chip_cookie_dough_ice_cream', 107), ('organic_1%_low_fat_milk', 108), ('organic_raw_unfiltered_apple_cider_vinegar', 109), ('natural_sharp_cheddar_sliced_cheese', 110), ('parsley__italian_(flat)__new_england_grown', 111), ('natural_artisan_water', 112), ('organic_romaine_leaf', 113), ('honey_yoghurt', 114), ('mini_cucumbers', 115), ('shells_&_real_aged_cheddar_macaroni_&_cheese', 116), ('organic_honey_sweet_whole_wheat_bread', 117), ('organic_no_salt_added_diced_tomatoes', 118), ('broccoli_&_cheddar_bake_meal_ ...
